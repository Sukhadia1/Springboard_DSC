# %% [markdown]
# # Building A Music Recommendation Engine

# %% [markdown]
# ### Importing required pakages

# %%
#Packages for data manipulation and visualization
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
import os
from datetime import datetime
import missingno as msno
from scipy import stats

#Packages for splitting data
from sklearn import base
from sklearn.model_selection import KFold

#Packages for controlling figure size
from IPython.core.pylabtools import figsize

# %%
#Getting Working Directory
os.getcwd()

#Setting style and font size for graphs
sns.set_style("whitegrid")
mpl.rcParams['font.size'] = 13

# %% [markdown]
# ### Importing Data from the CSV file

# %%
# %%time
#load original data into dataframe
train_file ='D:\\Abhishek\\Personal\\Springboard\\music_recom\\train.csv'
test_file ='D:\\Abhishek\\Personal\\Springboard\\music_recom\\test.csv'
songs_file ='D:\\Abhishek\\Personal\\Springboard\\music_recom\\songs.csv'
members_file ='D:\\Abhishek\\Personal\\Springboard\\music_recom\\members.csv'
songs_ex_file ='D:\\Abhishek\\Personal\\Springboard\\music_recom\\song_extra_info.csv'
train = pd.read_csv(train_file)#, na_values = '?')
test = pd.read_csv(test_file)
songs = pd.read_csv(songs_file)
members = pd.read_csv(members_file)
songs_ex = pd.read_csv(songs_ex_file)
# Out:
# Wall time: 23.1 s

# %% [markdown]
# ### Understanding the Data.
# Number of columns, whether it was imported correctly, number of missing values etc.

# %%
#check shape of the dataset and its columns
print("Train Shape", train.shape)
print("Test Shape", test.shape)
print("Songs Shape", songs.shape)
print("Members Shape", members.shape)
print("songs_extra_info Shape", songs_ex.shape)
# Out:
# Train Shape (7377418, 6)
# Test Shape (2556790, 6)
# Songs Shape (2296320, 7)
# Members Shape (34403, 7)
# songs_extra_info Shape (2295971, 3)

# %%
train.head()
# Out:
#                                            msno  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
#
#                                         song_id source_system_tab  \
# 0  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=           explore
# 1  bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=        my library
# 2  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=        my library
# 3  2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=        my library
# 4  3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=           explore
#
#     source_screen_name      source_type  target
# 0              Explore  online-playlist       1
# 1  Local playlist more   local-playlist       1
# 2  Local playlist more   local-playlist       1
# 3  Local playlist more   local-playlist       1
# 4              Explore  online-playlist       1

# %%
#Checking if the data was imported correctly
train.info()
test.info()
songs.info()
members.info()
songs_ex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7377418 entries, 0 to 7377417
# Data columns (total 6 columns):
# msno                  object
# song_id               object
# source_system_tab     object
# source_screen_name    object
# source_type           object
# target                int64
# dtypes: int64(1), object(5)
# memory usage: 337.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2556790 entries, 0 to 2556789
# Data columns (total 6 columns):
# id                    int64
# msno                  object
# song_id               object
# source_system_tab     object
# source_screen_name    object
# source_type           object
# dtypes: int64(1), object(5)
# memory usage: 117.0+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2296320 entries, 0 to 2296319
# Data columns (total 7 columns):
# song_id        object
# song_length    int64
# genre_ids      object
# artist_name    object
# composer       object
# lyricist       object
# language       float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 122.6+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34403 entries, 0 to 34402
# Data columns (total 7 columns):
# msno                      34403 non-null object
# city                      34403 non-null int64
# bd                        34403 non-null int64
# gender                    14501 non-null object
# registered_via            34403 non-null int64
# registration_init_time    34403 non-null int64
# expiration_date           34403 non-null int64
# dtypes: int64(5), object(2)
# memory usage: 1.8+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2295971 entries, 0 to 2295970
# Data columns (total 3 columns):
# song_id    object
# name       object
# isrc       object
# dtypes: object(3)
# memory usage: 52.6+ MB

# %%
train = train.merge(songs, how = 'left', on = 'song_id')
train = train.merge(members, how = 'left', on = 'msno')
train = train.merge(songs_ex, how = 'left', on = 'song_id')
train.head()
# Out:
#                                            msno  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
#
#                                         song_id source_system_tab  \
# 0  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=           explore
# 1  bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=        my library
# 2  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=        my library
# 3  2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=        my library
# 4  3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=           explore
#
#     source_screen_name      source_type  target  song_length genre_ids  \
# 0              Explore  online-playlist       1     206471.0       359
# 1  Local playlist more   local-playlist       1     284584.0      1259
# 2  Local playlist more   local-playlist       1     225396.0      1259
# 3  Local playlist more   local-playlist       1     255512.0      1019
# 4              Explore  online-playlist       1     187802.0      1011
#
#        artist_name                                 composer lyricist  \
# 0         Bastille                     Dan Smith| Mark Crew      NaN
# 1  Various Artists                                      NaN      NaN
# 2              Nas     N. Jones、W. Adams、J. Lordan、D. Ingle      NaN
# 3         Soundway                            Kwadwo Donkoh      NaN
# 4      Brett Young  Brett Young| Kelly Archer| Justin Ebach      NaN
#
#    language  city  bd  gender  registered_via  registration_init_time  \
# 0      52.0     1   0     NaN               7                20120102
# 1      52.0    13  24  female               9                20110525
# 2      52.0    13  24  female               9                20110525
# 3      -1.0    13  24  female               9                20110525
# 4      52.0     1   0     NaN               7                20120102
#
#    expiration_date                                     name          isrc
# 0         20171005                               Good Grief  GBUM71602854
# 1         20170911                       Lords of Cardboard  US3C69910183
# 2         20170911  Hip Hop Is Dead(Album Version (Edited))  USUM70618761
# 3         20170911                             Disco Africa  GBUQH1000063
# 4         20171005                        Sleep Without You  QM3E21606003

# %%
train.shape
# Out:
# (7377418, 20)

# %%
test = test.merge(songs, how = 'left', on = 'song_id')
test = test.merge(members, how = 'left', on = 'msno')
test = test.merge(songs_ex, how = 'left', on = 'song_id')
test.head()
# Out:
#    id                                          msno  \
# 0   0  V8ruy7SGk7tDm3zA51DPpn6qutt+vmKMBKa21dp54uM=
# 1   1  V8ruy7SGk7tDm3zA51DPpn6qutt+vmKMBKa21dp54uM=
# 2   2  /uQAlrAkaczV+nWCd2sPF2ekvXPRipV7q0l+gbLuxjw=
# 3   3  1a6oo/iXKatxQx4eS9zTVD+KlSVaAFbTIqVvwLC1Y0k=
# 4   4  1a6oo/iXKatxQx4eS9zTVD+KlSVaAFbTIqVvwLC1Y0k=
#
#                                         song_id source_system_tab  \
# 0  WmHKgKMlp1lQMecNdNvDMkvIycZYHnFwDT72I5sIssc=        my library
# 1  y/rsZ9DC7FwK5F2PK2D5mj+aOBUJAjuu3dZ14NgE0vM=        my library
# 2  8eZLFOdGVdXBSqoAv5nsLigeH2BvKXzTQYtUM53I0k4=          discover
# 3  ztCf8thYsS4YN3GcIL/bvoxLm/T5mYBVKOO4C9NiVfQ=             radio
# 4  MKVMpslKcQhMaFEgcEQhEfi5+RZhMYlU3eRDpySrH8Y=             radio
#
#     source_screen_name          source_type  song_length genre_ids  \
# 0  Local playlist more        local-library     224130.0       458
# 1  Local playlist more        local-library     320470.0       465
# 2                  NaN  song-based-playlist     315899.0      2022
# 3                Radio                radio     285210.0       465
# 4                Radio                radio     197590.0       873
#
#           artist_name                                   composer  \
# 0  梁文音 (Rachel Liang)                             Qi Zheng Zhang
# 1        林俊傑 (JJ Lin)                                        林俊傑
# 2  Yu Takahashi (高橋優)                               Yu Takahashi
# 3                  U2  The Edge| Adam Clayton| Larry Mullen| Jr.
# 4       Yoga Mr Sound                                Neuromancer
#
#        lyricist  language  city  bd gender  registered_via  \
# 0           NaN       3.0     1   0    NaN               7
# 1       孫燕姿/易家揚       3.0     1   0    NaN               7
# 2  Yu Takahashi      17.0     1   0    NaN               4
# 3           NaN      52.0     3  30   male               9
# 4           NaN      -1.0     3  30   male               9
#
#    registration_init_time  expiration_date  \
# 0                20160219         20170918
# 1                20160219         20170918
# 2                20161117         20161124
# 3                20070725         20170430
# 4                20070725         20170430
#
#                                    name          isrc
# 0                                愛其實很殘忍  TWUM71400047
# 1                                    她說  TWB671005201
# 2                   subarashiki nichijo  JPWP01070260
# 3  Hold Me| Thrill Me| Kiss Me| Kill Me  GBAAN0201228
# 4                               Om Yoga  ITO101121898

# %%
test.shape
# Out:
# (2556790, 20)

# %%
#Converting integer time columns to string so that converting to date becomes easy
train.registration_init_time = train.registration_init_time.astype('str')
train.expiration_date = train.expiration_date.astype('str')

#
train.registration_init_time = pd.to_datetime(train.registration_init_time, infer_datetime_format = True)
train.expiration_date = pd.to_datetime(train.expiration_date, infer_datetime_format = True)
train.head()
# Out:
#                                            msno  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
#
#                                         song_id source_system_tab  \
# 0  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=           explore
# 1  bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=        my library
# 2  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=        my library
# 3  2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=        my library
# 4  3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=           explore
#
#     source_screen_name      source_type  target  song_length genre_ids  \
# 0              Explore  online-playlist       1     206471.0       359
# 1  Local playlist more   local-playlist       1     284584.0      1259
# 2  Local playlist more   local-playlist       1     225396.0      1259
# 3  Local playlist more   local-playlist       1     255512.0      1019
# 4              Explore  online-playlist       1     187802.0      1011
#
#        artist_name                                 composer lyricist  \
# 0         Bastille                     Dan Smith| Mark Crew      NaN
# 1  Various Artists                                      NaN      NaN
# 2              Nas     N. Jones、W. Adams、J. Lordan、D. Ingle      NaN
# 3         Soundway                            Kwadwo Donkoh      NaN
# 4      Brett Young  Brett Young| Kelly Archer| Justin Ebach      NaN
#
#    language  city  bd  gender  registered_via registration_init_time  \
# 0      52.0     1   0     NaN               7             2012-01-02
# 1      52.0    13  24  female               9             2011-05-25
# 2      52.0    13  24  female               9             2011-05-25
# 3      -1.0    13  24  female               9             2011-05-25
# 4      52.0     1   0     NaN               7             2012-01-02
#
#   expiration_date                                     name          isrc
# 0      2017-10-05                               Good Grief  GBUM71602854
# 1      2017-09-11                       Lords of Cardboard  US3C69910183
# 2      2017-09-11  Hip Hop Is Dead(Album Version (Edited))  USUM70618761
# 3      2017-09-11                             Disco Africa  GBUQH1000063
# 4      2017-10-05                        Sleep Without You  QM3E21606003

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7377418 entries, 0 to 7377417
# Data columns (total 20 columns):
# msno                      object
# song_id                   object
# source_system_tab         object
# source_screen_name        object
# source_type               object
# target                    int64
# song_length               float64
# genre_ids                 object
# artist_name               object
# composer                  object
# lyricist                  object
# language                  float64
# city                      int64
# bd                        int64
# gender                    object
# registered_via            int64
# registration_init_time    datetime64[ns]
# expiration_date           datetime64[ns]
# name                      object
# isrc                      object
# dtypes: datetime64[ns](2), float64(2), int64(4), object(12)
# memory usage: 1.2+ GB

# %% [markdown]
# ## Missing Value Analysis

# %% [markdown]
# ### Finding our features with missing value

# %%
# Creating a empty table to store Missing Values Count

def missing_values(data):
    m_table = pd.DataFrame(columns = ['feature_name', 'null_values', '%missing', 'category_count'])
    #Counting the missing values and appending it to m_table
    for col in data.columns:
        null_count = data[col].isnull().sum()
        missing = round((null_count/len(train))*100,2)
        count = len(data[col].unique())
        m_table = m_table.append(pd.Series([col, null_count, missing,count],index = m_table.columns),ignore_index=True)

    #Displaying features which has missing values in descending order
    missing = m_table[m_table.null_values != 0].sort_values(by = '%missing',ascending = False).reset_index(drop = True)
    display('Missing Value Table')
    display(missing)
    print('\n')

# %%
print('Train Data')
print(missing_values(train))
# Out:
# Train Data
# 'Missing Value Table'
#           feature_name null_values  %missing category_count
# 0             lyricist     3178798     43.09          33889
# 1               gender     2961479     40.14              3
# 2             composer     1675706     22.71          76065
# 3                 isrc      577858      7.83         269761
# 4   source_screen_name      414804      5.62             21
# 5            genre_ids      118455      1.61            573
# 6    source_system_tab       24849      0.34              9
# 7          source_type       21539      0.29             13
# 8                 name        1457      0.02         234145
# 9          song_length         114      0.00          60267
# 10         artist_name         114      0.00          40583
# 11            language         150      0.00             11
# None

# %%
msno.heatmap(train)

# %%
print('Test Data')
print(missing_values(test))
# Out:
# Test Data
# 'Missing Value Table'
#           feature_name null_values  %missing category_count
# 0             lyricist     1224744     16.60          24911
# 1               gender     1052224     14.26              3
# 2             composer      619304      8.39          52307
# 3                 isrc      196643      2.67         170988
# 4   source_screen_name      162883      2.21             23
# 5            genre_ids       42110      0.57            502
# 6    source_system_tab        8442      0.11              9
# 7          source_type        7297      0.10             13
# 8                 name         778      0.01         154717
# 9          song_length          25      0.00          45658
# 10         artist_name          25      0.00          27564
# 11            language          42      0.00             11
# None

# %%
msno.heatmap(test)

# %%
train[~train.song_length.isna() & train.composer.isna()]
# Out:
#                                                  msno  \
# 1        Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 22       uQQHTQJ1nVEkBfbXe0f1/J9ML5eQhsQiocCV5TvvCRI=
# 26       pouJqjNRmZOnRNzzMWWkamTKkIGHyvhl/jo4HgbncnM=
# 30       Vgeu+u3vXE0FhQtG/Vr3I/U3V0TX/jzQAEBhi3S3qi0=
# 42       HkWEvfQyrb5Lve8X3B7HkCEkDFW8qFy/9kWFb4QbM5k=
# 56       1GH1R7OI417+PPoqBtb9Jh1udsZC5XrOW2HqwjzCl2A=
# 59       1GH1R7OI417+PPoqBtb9Jh1udsZC5XrOW2HqwjzCl2A=
# 73       mxAnVRJaxt6zsH6/lpKp6tUjs7dAh9a6RMTPrNuqm44=
# 76       CL91UAbjYfhlEg1Yjh10QStr0liu9B/yImCGHlpiEMI=
# 77       yABGsFFqTctk/xnMj67nHmnisCwdue7XYxkYGOe9BGE=
# 80       Gz/bwq6vWwkm5QQOCd3ftP4F4mMthEFGf3ztaXgm6e0=
# 82       Gz/bwq6vWwkm5QQOCd3ftP4F4mMthEFGf3ztaXgm6e0=
# 117      gkWsUPNQVsVvEjihLMbIZlriQbV+YyFVMB42melpJhI=
# 118      gkWsUPNQVsVvEjihLMbIZlriQbV+YyFVMB42melpJhI=
# 120      gkWsUPNQVsVvEjihLMbIZlriQbV+YyFVMB42melpJhI=
# 126      XIpjLNs4f/OHphnrSPoNmsrd45Al8pL0v74FgzDZHnQ=
# 129      AXKTVBbdr2/z7m5WL1IXzlriNbun8B+7wM41MsWCYDw=
# 130      AXKTVBbdr2/z7m5WL1IXzlriNbun8B+7wM41MsWCYDw=
# 133      AXKTVBbdr2/z7m5WL1IXzlriNbun8B+7wM41MsWCYDw=
# 139      ocdN6b9BP9Qr0B8q6+UNpcBvfErNMk8P6Ny5CK3CyKA=
# 141      ocdN6b9BP9Qr0B8q6+UNpcBvfErNMk8P6Ny5CK3CyKA=
# 143      hE9WBNEn/Wv0qSG2hB7/C4oQStAxcGJgRnpn3ZY/abw=
# 144      hE9WBNEn/Wv0qSG2hB7/C4oQStAxcGJgRnpn3ZY/abw=
# 146      hE9WBNEn/Wv0qSG2hB7/C4oQStAxcGJgRnpn3ZY/abw=
# 147      hE9WBNEn/Wv0qSG2hB7/C4oQStAxcGJgRnpn3ZY/abw=
# 149      hE9WBNEn/Wv0qSG2hB7/C4oQStAxcGJgRnpn3ZY/abw=
# 154      vmpdGkTolfjP2xTna7cYfeRpt/31h0lvHEu2GdXjqm0=
# 162      PQfNQQon0CwOLghOAyztQYVw6yJTVgmFpJ650q/UF1s=
# 169      LGIeu7rj6KryPWev2nr5g807ZPtw4b59wqDn5jighcw=
# 173      69zw2q5cjT4DcLpn+7UAETUg5cFAZTRF3885oqpMQ3U=
# ...                                               ...
# 7377306  erpolDJCn1LcaMtQv8owSw/PwBC9PLTh079qJusqXm4=
# 7377309  erpolDJCn1LcaMtQv8owSw/PwBC9PLTh079qJusqXm4=
# 7377316  sZ/9Tn2NmzyJJVH1Vry+KUICQ9qa+uFwkuyyLyXSwto=
# 7377318  sZ/9Tn2NmzyJJVH1Vry+KUICQ9qa+uFwkuyyLyXSwto=
# 7377319  sZ/9Tn2NmzyJJVH1Vry+KUICQ9qa+uFwkuyyLyXSwto=
# 7377328  98tCxpFWl3C95vAK27UDxTerXBddeQFQXchUbSWdADw=
# 7377335  //4hBneqk/4/TtgL1XXQ+eKx7fJTeSvSNt0ktxjSIYE=
# 7377336  //4hBneqk/4/TtgL1XXQ+eKx7fJTeSvSNt0ktxjSIYE=
# 7377337  //4hBneqk/4/TtgL1XXQ+eKx7fJTeSvSNt0ktxjSIYE=
# 7377338  //4hBneqk/4/TtgL1XXQ+eKx7fJTeSvSNt0ktxjSIYE=
# 7377339  //4hBneqk/4/TtgL1XXQ+eKx7fJTeSvSNt0ktxjSIYE=
# 7377340  //4hBneqk/4/TtgL1XXQ+eKx7fJTeSvSNt0ktxjSIYE=
# 7377343  4pK8Ase2ZizP+fW6g3X4t4vCnU9Gj9X/4pQRzLsY5DI=
# 7377344  4pK8Ase2ZizP+fW6g3X4t4vCnU9Gj9X/4pQRzLsY5DI=
# 7377345  4pK8Ase2ZizP+fW6g3X4t4vCnU9Gj9X/4pQRzLsY5DI=
# 7377346  4pK8Ase2ZizP+fW6g3X4t4vCnU9Gj9X/4pQRzLsY5DI=
# 7377357  HmPt2ejCDD7yrFi9k3Z9YUS1PbcQhFdaRCECNk6Levk=
# 7377360  HmPt2ejCDD7yrFi9k3Z9YUS1PbcQhFdaRCECNk6Levk=
# 7377364  dl95Mp7//hpzmmyl1YlF00IUqi6pY9VQhbCTQvQtdUA=
# 7377368  O3CsBhmCxwqe8acAy5Xdc4FQQoRgkHZrYJ8SxxOkbD8=
# 7377383  zwnnOtHeooUKwmZC2XN5B/1aTi97HN8iMGpzX5Iq16o=
# 7377384  W30MtdCWtu8FZGGZIQ14yT+I0iUxaqEZ3AJPUW3VfYk=
# 7377385  jnWlUt2FGlgchWH6TWGggWnrxd969y4LyzEgstf4VwU=
# 7377392  EOlbX3GsW3ObXy/9ykwK2RQqHK6vDQWmv+BtQ8efMrk=
# 7377393  EOlbX3GsW3ObXy/9ykwK2RQqHK6vDQWmv+BtQ8efMrk=
# 7377396  muqxBsLGNBqgLUB0gfMwpP04Ittx6rfPP8wLU8sxL6o=
# 7377402  CRo1X/++zVnTpjJ4RzHSKzQCjUjn5FK11LtDWgGKtrY=
# 7377404  CRo1X/++zVnTpjJ4RzHSKzQCjUjn5FK11LtDWgGKtrY=
# 7377406  tNY8feCyKR2/eHxT1Bjuf+IfSQM/1IyscPJHqy2lFug=
# 7377416  0aH4Hd3ziPSRHClRX8rkeOEaAG5EPPkW1mKGCdXEok0=
#
#                                               song_id source_system_tab  \
# 1        bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=        my library
# 22       lrgjGNzyCHrMPfLKNMV0NBh9hdNTpzoj5rOZ27tXMLo=        my library
# 26       TLUDFNRpLCG/DmqLiXBc4Udypwucj4XmKtotIUO6nXM=        my library
# 30       TE5ASd0CqSedf7+LBnqf5Z8Kfm9X9wfj8t2IXZNuDOw=        my library
# 42       vM08WBQRO9eZo1K+qTJmjuw2IqbuA3L65ojbGwB4GI0=        my library
# 56       iXbxmEpOCNBNj9ty45gPuwtYvUqQBOKNsXANX25joiY=        my library
# 59       IPeg6L8QvmfJTuOFNa4iPnk93WzyceWdxnVDCreoEpE=        my library
# 73       n8xoFetUt29W6E4Gxnz8SGKewVBDSTtLdZ913mb4Hzg=        my library
# 76       2fhzNUTd3X1n8IKBAd0xM2HwOuDIc0Qb6ZcVQ3OmqX4=        my library
# 77       RAVcXkNI6tqrsArzBxA9JcNnv/ftDwqDwBDaGqIzXyA=        my library
# 80       CUPwUKwyAEXwoQw8ik8EyfskXSvEUpu3Pb3mS2yFXoI=        my library
# 82       boxeSDj5nrUIRE0JoCMKUBxk/c4dsKf49yacI6WPHoc=        my library
# 117      zoGrsIvu2CqHccUYgzhXqhXqQq5/G1eQN0wHHO9EyV4=        my library
# 118      yPA+sQt5tJ3NgR6/L9BefmNpA2152zQQ+/Kvtt3iSUs=        my library
# 120      wYrDzOG0yorZni7WBtsr3QrCt7Huaj3aLEC0QWaZdFs=        my library
# 126      3VkD5ekIf5duJm1hmYTZlXjyl0zqV8wCzuAh3uocfCg=        my library
# 129      SdrJPjGVS23rS7eNdmTe4h7SX8WAFeSja5XTejy3S0o=          discover
# 130      yIllJ0cE7535hEXIzaQp0ePMojoOmkBYaXV8z1y+0c4=          discover
# 133      iGQWuI/3FeZrHKxt1Yy0A2cfqTFSiNN6DoxnKkb6h5g=          discover
# 139      dSkGPyBKM97xpD3mOsCmhwSLO42eLuqBaDAamdZNBkI=            search
# 141      S+lF2rQKunOeEhqeQRQrQhFWal/bfdeAr5i35Qu72+0=        my library
# 143      r01XmbdwG4sqS8ZA7tIx+VAuxrXNuDu7siNQB+Q2jrs=        my library
# 144      u70RByc176rGRQLAmXdf7WNM0vU2RrkkYnY7z1wOPyA=        my library
# 146      wzhGVAOKC5tmBWI7xc/c3NJomswOMoZwsDDifhC5wEo=        my library
# 147      0vBTdkfbCDjBihoqg+UAEIkuFS+6WUmTpgv+iPHP9fY=        my library
# 149      /tRJOn8mjgWkOnGmG7h43o4hClfmi5hZ9F2r5ZL8F/k=        my library
# 154      5pSFbaPtNR/DZ6pHuKOqRehOK2Jrf5TUxxd4org8HxU=        my library
# 162      tVAxrAlDEmQvSc4xfh4Sd5wvV6oIgHi8DJvtfJhGwzs=          discover
# 169      0ee/D6HjX0jSytUn3v58C0x6zEzN4bcPq3WlqvrG/Xo=          discover
# 173      GQqErVwbH/YaifR6wl2S6prosRVHhwGO2/Aq5aIJLA8=        my library
# ...                                               ...               ...
# 7377306  LWqUJRIEm3OAIOG9gxirv855L9Z1l2ypfeN3+wv3uqs=        my library
# 7377309  mRqErcILmDL3tSeY/phdw48akc8X+LgVs6NodmnMvV8=        my library
# 7377316  djtmsDFBXOoNe8rx7BuY55qKD5eLrZNDjWYJtDX/lj8=            search
# 7377318  DyEEXhRxrcEUziBGckuw9qVoxttK2qm9m3Dn1Z6aqZI=            search
# 7377319  DzyfIdvh+mj9aHJos4f92j/fGhF7/ucKFtTt3K9xXOM=            search
# 7377328  JP0GJixHOHSNDsjKiQY2ttQKbDmWSk35JMMfPtR06BM=          discover
# 7377335  cjFcw6k2T1Loci4oAHn/Ob5b29zOSUqlTC6I1bodGF4=            search
# 7377336  ZvQjd+l83+MnLmFIdIU264CfrtUBcKxOpr3UBBYp1Bk=            search
# 7377337  9C/pDOdVTSuPd3uQFrlCRk1Ljk5oNTMSLklUU4lS//I=            search
# 7377338  yeWoUcjnEnE3BI+bq0Gi94azpn5t6vBVThbbR/veh3g=            search
# 7377339  68tvxUiYyQb4C17D0h+fXn7YmqMCX/HKhWSzit/UlAo=            search
# 7377340  lu7E716NnSKmad9WXY7pMMt4rd/eT5RlCUBvHNkkpVQ=            search
# 7377343  aU0AQq1w8LMpqgg6GOq2iOQdyuoFvi0ODxvCdsicyKU=          discover
# 7377344  Jqko13VHRLzha0Tq7DK1tQrsSmLsYV1T3mOfCj8YQC8=          discover
# 7377345  EoD6cAOtWE+eLz6ABk5mjXwhA8KkHRJkg/sKpR2ffes=          discover
# 7377346  YCtGQCYyO2bl345LRdyNjIIPLGgLbTubSt/l7oCEcII=          discover
# 7377357  atryS5vHTUSHtmjMZbXTWDRnK13f/C601y09MokzsrQ=        my library
# 7377360  ga/Ws9ufkv2/8gzA+HpIr4bVoyO8xtDY3fo8mRiG5Ck=        my library
# 7377364  cSxS44EeEvagcnSkd42T0AxhasiedvRIHaLLxKfd03E=          discover
# 7377368  vdbUGlcRq3cB0XvkCYSTlMEVYMKEDlGauRA7iElyxXQ=        my library
# 7377383  TTDHpUNFO6cFrVguTkrELP8qkwDfIMjFzR6d4WCe7rA=            search
# 7377384  eh6yQhwK9cLrb8fhmE+q+gUFpmCuG6yUKELeQH5XxM4=        my library
# 7377385  9EALY+No104Qw3Wd/MK4q0Lnj1EVDpK74Vh993V0bQA=        my library
# 7377392  Ns0SppZ33iTxc7NrGrKgS0NYaG0ssLvkdB9nQxlNB18=            search
# 7377393  yMO5SoJEF+HXxfvAqDLl2dLhiFaTCIdeDXrOdBWQPIQ=            search
# 7377396  xPOep/X2ck9EtyC7KlQpbkO4G6fmtQiMtKawVks9J/A=        my library
# 7377402  9NrqJ36mURDvRECILJfsJuPPNBz/Lq39YANZBuYbTeg=          discover
# 7377404  FLpi0+Ral1r9kzNRSb4MfZwATX1iYG1HLR4Fxl3cMJo=          discover
# 7377406  ymxTQ1U+c6/GnVCRrO/voyJbhoaP+To3rSh5IFWfX/Y=           explore
# 7377416  G8wgqObgeAMER/rVCIlgcNeQ8mm0CzF/GsxiMK8TTnA=          discover
#
#            source_screen_name          source_type  target  song_length  \
# 1         Local playlist more       local-playlist       1     284584.0
# 22        Local playlist more        local-library       1     257671.0
# 26       Online playlist more      online-playlist       0     307200.0
# 30        Local playlist more        local-library       1     183484.0
# 42        Local playlist more        local-library       0     284908.0
# 56        Local playlist more       local-playlist       1     203685.0
# 59        Local playlist more       local-playlist       1     184366.0
# 73        Local playlist more        local-library       1     187988.0
# 76                 My library       local-playlist       1     375849.0
# 77        Local playlist more        local-library       1     229784.0
# 80        Local playlist more        local-library       1     310439.0
# 82        Local playlist more        local-library       1     292048.0
# 117       Local playlist more       local-playlist       1     276363.0
# 118       Local playlist more       local-playlist       1     286876.0
# 120       Local playlist more       local-playlist       1     246073.0
# 126       Local playlist more       local-playlist       1     217730.0
# 129          Discover Feature                album       0     143034.0
# 130          Discover Feature                album       0      94923.0
# 133          Discover Feature                album       1     274808.0
# 139      Online playlist more      online-playlist       0     254537.0
# 141       Local playlist more        local-library       1     294707.0
# 143                Album more                album       0      35944.0
# 144                Album more                album       0      57678.0
# 146                Album more                album       0     210024.0
# 147                    Search      online-playlist       0     161123.0
# 149                Album more                album       0      24346.0
# 154       Local playlist more        local-library       1     303647.0
# 162                       NaN  top-hits-for-artist       1     261433.0
# 169      Online playlist more  song-based-playlist       1     195944.0
# 173       Local playlist more       local-playlist       1     177562.0
# ...                       ...                  ...     ...          ...
# 7377306   Local playlist more       local-playlist       0     241998.0
# 7377309   Local playlist more       local-playlist       0     248163.0
# 7377316            Album more                album       1     177737.0
# 7377318           Artist more  top-hits-for-artist       1     170109.0
# 7377319           Artist more  top-hits-for-artist       1     224757.0
# 7377328                   NaN      online-playlist       0     285466.0
# 7377335                Search                album       0     106370.0
# 7377336                Search                album       1      71888.0
# 7377337                Search                album       0     205426.0
# 7377338                Search                album       0     168333.0
# 7377339                Search                album       0     230063.0
# 7377340                Search                album       0     223399.0
# 7377343                   NaN  top-hits-for-artist       0     260202.0
# 7377344                   NaN  top-hits-for-artist       0     368128.0
# 7377345                   NaN  top-hits-for-artist       0     332091.0
# 7377346                   NaN  top-hits-for-artist       0     301998.0
# 7377357   Local playlist more        local-library       0     251533.0
# 7377360   Local playlist more        local-library       1     208515.0
# 7377364                   NaN      online-playlist       0     187559.0
# 7377368                   NaN  top-hits-for-artist       1     188708.0
# 7377383           Artist more  top-hits-for-artist       0     241394.0
# 7377384   Local playlist more        local-library       1     236146.0
# 7377385   Local playlist more        local-library       0     259239.0
# 7377392            Album more                album       0     291840.0
# 7377393            Album more                album       0     248999.0
# 7377396   Local playlist more        local-library       0     306549.0
# 7377402                   NaN  song-based-playlist       0     166217.0
# 7377404                   NaN  song-based-playlist       0     185016.0
# 7377406  Online playlist more      online-playlist       0     198008.0
# 7377416        Discover Genre      online-playlist       1     524146.0
#
#         genre_ids                                   artist_name composer  \
# 1            1259                               Various Artists      NaN
# 22            465                                  五月天 (Mayday)      NaN
# 26            465  Pleasantville -Music From The Motion Picture      NaN
# 30            465                                         S.H.E      NaN
# 42            921                               Various Artists      NaN
# 56            465                                           EXO      NaN
# 59            465                                           EXO      NaN
# 73            465                               Imagine Dragons      NaN
# 76            465                               伍佰 & China Blue      NaN
# 77            465                                      FTISLAND      NaN
# 80            465                               伍佰 & China Blue      NaN
# 82            465                          動力火車 (Power Station)      NaN
# 117           465                                        台語精選原版      NaN
# 118           465                              蔡依林 (Jolin Tsai)      NaN
# 120           465                                    呂建中 (Tank)      NaN
# 126           465                                  CHARLIE PUTH      NaN
# 129           921                               Various Artists      NaN
# 130           921                               Various Artists      NaN
# 133           465                              Everlasting Love      NaN
# 139           458                              曲婉婷 (Wanting Qu)      NaN
# 141           829                                            黃玠      NaN
# 143           465                                HAPPY BIRTHDAY      NaN
# 144       921|465                                     生日快樂電影原聲帶      NaN
# 146       921|465                                     生日快樂電影原聲帶      NaN
# 147           458                             張懸 (Deserts Xuan)      NaN
# 149       921|465                                     生日快樂電影原聲帶      NaN
# 154           465                               庾澄慶 (Harlem Yu)      NaN
# 162           465                                 李聖傑 (Sam Lee)      NaN
# 169           359                             twenty one pilots      NaN
# 173           359                               Imagine Dragons      NaN
# ...           ...                                           ...      ...
# 7377306       465                                           張震嶽      NaN
# 7377309       465                             阿妹妹 (Raya & Saya)      NaN
# 7377316       465                               范曉萱 (Mavis Fan)      NaN
# 7377318       465                               范曉萱 (Mavis Fan)      NaN
# 7377319       465                               范曉萱 (Mavis Fan)      NaN
# 7377328       465                              陳勢安 (Andrew Tan)      NaN
# 7377335       359                                   Linkin Park      NaN
# 7377336       359                                   Linkin Park      NaN
# 7377337       359                                   Linkin Park      NaN
# 7377338       359                                   Linkin Park      NaN
# 7377339       359                                   Linkin Park      NaN
# 7377340       359                                   Linkin Park      NaN
# 7377343       465              童安格+周治平 (Angus Tung +Steve Chow)      NaN
# 7377344       465              童安格+周治平 (Angus Tung +Steve Chow)      NaN
# 7377345       465              童安格+周治平 (Angus Tung +Steve Chow)      NaN
# 7377346       465              童安格+周治平 (Angus Tung +Steve Chow)      NaN
# 7377357      1259                                          T.I.      NaN
# 7377360      1259                                      Flo Rida      NaN
# 7377364       444                                           INA      NaN
# 7377368       465                                         Twins      NaN
# 7377383       465                                      Coldplay      NaN
# 7377384      1259                                熱狗 (MC HotDog)      NaN
# 7377385       444                               Jung Joon Young      NaN
# 7377392       465                                           王識賢      NaN
# 7377393       465                                           王識賢      NaN
# 7377396       465                               蘇打綠 (Sodagreen)      NaN
# 7377402      1609                                   MAJOR LAZER      NaN
# 7377404      1609                                        Baauer      NaN
# 7377406       786                                        寶寶水晶音樂      NaN
# 7377416      2122                             Brad Mehldau Trio      NaN
#
#                                                   lyricist  language  city  \
# 1                                                      NaN      52.0    13
# 22                                                     NaN       3.0     9
# 26                                                     NaN      52.0    15
# 30                                                     藍小邪       3.0     1
# 42                                                     NaN       3.0    15
# 56                                                     NaN      31.0    13
# 59       Chung| Joo Hee/Greg Paul Stephen Bonnick (LDN ...      31.0    13
# 73                                                     NaN      52.0     1
# 76                                                     NaN       3.0    22
# 77                                                     NaN      31.0    13
# 80                                                     NaN       3.0     1
# 82                                                     NaN       3.0     1
# 117                                                    NaN      10.0    13
# 118                                                    NaN       3.0    13
# 120                                                    NaN       3.0    13
# 126                                                    NaN      52.0     4
# 129                                                    NaN      52.0     1
# 130                                                    NaN      52.0     1
# 133                                                    NaN      52.0     1
# 139                                                    NaN       3.0     1
# 141                                                    NaN       3.0     1
# 143                                      HILL| PATTY SMITH      52.0    13
# 144                                                    NaN       3.0    13
# 146                                                    NaN       3.0    13
# 147                                                    NaN       3.0    13
# 149                                                    NaN       3.0    13
# 154                                                    NaN       3.0     4
# 162                                                    NaN       3.0    22
# 169                                                    NaN      52.0    13
# 173                                                    NaN      52.0     1
# ...                                                    ...       ...   ...
# 7377306                                                NaN       3.0     4
# 7377309                                                NaN       3.0     4
# 7377316                                                許常德       3.0     1
# 7377318                                                NaN       3.0     1
# 7377319                                                NaN       3.0     1
# 7377328                                                NaN       3.0     1
# 7377335                                                NaN      52.0    12
# 7377336                                                NaN      52.0    12
# 7377337                                                NaN      52.0    12
# 7377338                                                NaN      52.0    12
# 7377339                                                NaN      52.0    12
# 7377340                                                NaN      52.0    12
# 7377343                                                NaN       3.0     1
# 7377344                                                NaN       3.0     1
# 7377345                                                NaN       3.0     1
# 7377346                                                NaN       3.0     1
# 7377357                                                NaN      52.0     5
# 7377360                                                NaN      52.0     5
# 7377364                                                NaN      31.0     3
# 7377368                                                NaN       3.0    18
# 7377383                                                NaN      52.0     6
# 7377384                                                NaN       3.0    22
# 7377385                                                NaN      31.0    15
# 7377392                                                NaN      10.0     6
# 7377393                                                NaN      10.0     6
# 7377396                                                NaN       3.0    15
# 7377402                                                NaN      52.0    22
# 7377404                                                NaN      52.0    22
# 7377406                                                NaN      -1.0     1
# 7377416                                                NaN      52.0     5
#
#          bd  gender  registered_via registration_init_time expiration_date  \
# 1        24  female               9             2011-05-25      2017-09-11
# 22       27  female               9             2013-09-12      2017-09-12
# 26       18    male               4             2015-12-20      2017-09-30
# 30        0     NaN               7             2010-12-05      2018-01-04
# 42       26  female               9             2006-06-16      2018-05-16
# 56       26  female               3             2013-04-05      2017-10-03
# 59       26  female               3             2013-04-05      2017-10-03
# 73        0     NaN               7             2016-03-04      2017-10-03
# 76       28  female               7             2013-07-07      2018-07-09
# 77       36  female               9             2011-06-23      2017-10-06
# 80        0     NaN               7             2013-09-02      2017-09-14
# 82        0     NaN               7             2013-09-02      2017-09-14
# 117      28    male               7             2010-10-22      2017-11-16
# 118      28    male               7             2010-10-22      2017-11-16
# 120      28    male               7             2010-10-22      2017-11-16
# 126      23  female               9             2011-10-29      2017-10-02
# 129       0     NaN               7             2010-11-18      2017-08-10
# 130       0     NaN               7             2010-11-18      2017-08-10
# 133       0     NaN               7             2010-11-18      2017-08-10
# 139       0     NaN               7             2015-09-14      2017-09-11
# 141       0     NaN               7             2015-09-14      2017-09-11
# 143      28  female               9             2012-07-13      2018-08-18
# 144      28  female               9             2012-07-13      2018-08-18
# 146      28  female               9             2012-07-13      2018-08-18
# 147      28  female               9             2012-07-13      2018-08-18
# 149      28  female               9             2012-07-13      2018-08-18
# 154       0     NaN               7             2012-07-01      2017-10-11
# 162      21  female               3             2014-11-02      2017-06-17
# 169      26  female               7             2012-05-14      2017-11-19
# 173       0     NaN               3             2013-10-27      2017-06-05
# ...      ..     ...             ...                    ...             ...
# 7377306  36  female               7             2011-09-24      2017-09-12
# 7377309  36  female               7             2011-09-24      2017-09-12
# 7377316   0     NaN               9             2015-03-28      2017-09-19
# 7377318   0     NaN               9             2015-03-28      2017-09-19
# 7377319   0     NaN               9             2015-03-28      2017-09-19
# 7377328   0     NaN               9             2015-11-09      2018-01-05
# 7377335  18  female               3             2014-10-28      2017-08-08
# 7377336  18  female               3             2014-10-28      2017-08-08
# 7377337  18  female               3             2014-10-28      2017-08-08
# 7377338  18  female               3             2014-10-28      2017-08-08
# 7377339  18  female               3             2014-10-28      2017-08-08
# 7377340  18  female               3             2014-10-28      2017-08-08
# 7377343   0     NaN               7             2011-11-09      2017-09-10
# 7377344   0     NaN               7             2011-11-09      2017-09-10
# 7377345   0     NaN               7             2011-11-09      2017-09-10
# 7377346   0     NaN               7             2011-11-09      2017-09-10
# 7377357  44  female               4             2016-09-17      2017-09-10
# 7377360  44  female               4             2016-09-17      2017-09-10
# 7377364  26  female               3             2014-03-14      2017-09-21
# 7377368  25    male               3             2011-12-15      2017-09-30
# 7377383   0     NaN               3             2014-02-05      2017-09-27
# 7377384  22  female               9             2014-10-18      2018-04-06
# 7377385  27    male               9             2014-12-24      2017-09-03
# 7377392  23    male               9             2008-11-29      2017-10-01
# 7377393  23    male               9             2008-11-29      2017-10-01
# 7377396  22    male               9             2011-03-06      2017-09-12
# 7377402  37  female               9             2006-03-02      2017-09-30
# 7377404  37  female               9             2006-03-02      2017-09-30
# 7377406   0     NaN               7             2014-01-12      2017-09-30
# 7377416   0     NaN               9             2015-02-13      2017-09-18
#
#                                         name          isrc
# 1                         Lords of Cardboard  US3C69910183
# 22                                       麥來亂  TWA450586306
# 26                       Across The Universe  USSM19803669
# 30                                      宇宙小姐  TWD950806103
# 42                                         零  TWA470441001
# 56                                     LUCKY  KRA301300169
# 59                                LIGHTSABER  KRA301500665
# 73                               Radioactive  USUM71201074
# 76                                     愛情的盡頭           NaN
# 77                             Gobaeghabnida  TWA531100324
# 80                                    一生最愛的人           NaN
# 82                                   忠孝東路走九遍           NaN
# 117                                       故鄉           NaN
# 118                                     第三人稱  TWA531457209
# 120                                      三國戀  TWD950522103
# 126                    We Don't Talk Anymore  USAT21502909
# 129                                Look Down  GBUM71207806
# 130                               The Bishop  GBUM71207807
# 133       Bridge Over Troubled Water(惡水上的大橋)           NaN
# 139                                     愛的勇氣  CAN111400333
# 141                                    下雨的晚上  QMDA71363931
# 143                          Happy Birthday!  DEHB20700052
# 144                               I MISS YOU  TWJ010600208
# 146                                     生日快樂  TWJ010600229
# 147                                       寶貝  TWA470601002
# 149                                       回憶  TWJ010600209
# 154                                  無盡透明的思念  TWB730910002
# 162                                     我懂了她  TWF750481606
# 169                                 Heathens  USAT21601930
# 173      Demons (電影「跨越世紀的情書」預告曲、美國職棒大聯盟一週好球)  USUM71201071
# ...                                      ...           ...
# 7377306                                愛的初體驗           NaN
# 7377309                               我要為你做飯  TWB519703901
# 7377316                                  健康歌  TWA219607701
# 7377318                                 我愛洗澡  TWA219710102
# 7377319                                   哭了  TWA219811403
# 7377328                                   天后  TWA531033402
# 7377335                           VICTIMIZED  USWB11200796
# 7377336                              TINFOIL  USWB11200800
# 7377337                      CASTLE OF GLASS  USWB11200795
# 7377338                         SKIN TO BONE  USWB11200798
# 7377339                     ROADS UNTRAVELED  USWB11200797
# 7377340                      UNTIL IT BREAKS  USWB11200799
# 7377343                                 一世情緣  TWA750700232
# 7377344                                  忘不了  TWA750700236
# 7377345                              玫瑰花瓣的信箋  TWA750700209
# 7377346                              我和我追逐的夢  TWA750700214
# 7377357                    Whatever You Like  USAT20803170
# 7377360           Jump (Feat. Nelly Furtado)  USAT20900453
# 7377364                              Rainbow  KRA381700013
# 7377368                                 我們之間  HKD251133902
# 7377383                         Viva La Vida  GBAYE0800265
# 7377384                                 謝謝啞唬  TWA450893205
# 7377385                          Where Are U  KRA381601403
# 7377392                                寄袂出的批           NaN
# 7377393                                   手指           NaN
# 7377396                              無與倫比的美麗  TWF670700305
# 7377402  Light It Up (feat. Nyla & Fuse ODG)  QMUY41500182
# 7377404                               Temple  GB5P51500097
# 7377406                               Longer           NaN
# 7377416                           Wonderwall  USNO10750721
#
# [1675592 rows x 20 columns]

# %%
#Replacing Missing values as "Category Name Missing" to create a separate category for string columns
train.lyricist.fillna('lyricist_missing', inplace = True)
train.gender.fillna('gender_missing', inplace = True)
train.composer.fillna('composer_missing', inplace = True)
train.source_screen_name.fillna('screen_name_missing', inplace = True)
train.genre_ids.fillna('genre_missing', inplace = True)
train.source_system_tab.fillna('system_tab_missing', inplace = True)
train.source_type.fillna('source_type_missing', inplace = True)
train.artist_name.fillna('artist_name_missing', inplace = True)
train.name.fillna('song_name_missing', inplace = True)
train.isrc.fillna('isrc_missing', inplace = True)

#Relacing missing values of language by -1
train.language.fillna(-1, inplace = True)

#Song Length missing values will be replaced post splitting of data so that leakage to test data doesn't happen.

# %%
#Replacing Missing values as "Category Name Missing" to create a separate category for string columns
test.lyricist.fillna('lyricist_missing', inplace = True)
test.gender.fillna('gender_missing', inplace = True)
test.composer.fillna('composer_missing', inplace = True)
test.source_screen_name.fillna('screen_name_missing', inplace = True)
test.genre_ids.fillna('genre_missing', inplace = True)
test.source_system_tab.fillna('system_tab_missing', inplace = True)
test.source_type.fillna('source_type_missing', inplace = True)
test.artist_name.fillna('artist_name_missing', inplace = True)
test.name.fillna('song_name_missing', inplace = True)
test.isrc.fillna('isrc_missing', inplace = True)

#Relacing missing values of language by -1
test.language.fillna(-1, inplace = True)

#Song Length missing values will be replaced post splitting of data so that leakage to test data doesn't happen.

# %% [markdown]
# #### Checking the distribution of age.
#      - Age has Negative values (-43 and -38)
#      - Age has outliers (<14 and >110)
#      - Age have values > 1000 as (1030 and 1051)
#      - 39.8% of Values have age as 0. Assuming this as missing values.

# %%
import seaborn as sns
_ = sns.distplot(train.bd, bins = 40)

# %%
train.bd.describe()
# Out:
# count    7.377418e+06
# mean     1.753927e+01
# std      2.155447e+01
# min     -4.300000e+01
# 25%      0.000000e+00
# 50%      2.100000e+01
# 75%      2.900000e+01
# max      1.051000e+03
# Name: bd, dtype: float64

# %% [markdown]
# #### Cleaning Age Column
#     - Making Negative values as positive values as they are data input error
#     - (> 1000) values are data input error so subtracting 1000 from such values
#     - for age between  1 to 13 and >110 considering them as missing values

# %%
def age_clean(age):
    if age < 0: 
        return(abs(age))
    elif age > 1000:
        return(age - 1000)
    elif (age > 0) & (age < 14):
        return 0
    elif (age > 110) & (age < 1000):
        return 0
    else: return age

# %%
train.bd = train.bd.apply(lambda x: age_clean(x))

# %%
train.bd.describe()
# Out:
# count    7.377418e+06
# mean     1.729543e+01
# std      1.567888e+01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      2.100000e+01
# 75%      2.900000e+01
# max      1.070000e+02
# Name: bd, dtype: float64

# %%
import seaborn as sns
_ = sns.distplot(train.bd, bins = 40)

# %%
missing_values(train)
# Out:
# 'Missing Value Table'
#   feature_name null_values  %missing category_count
# 0  song_length         114       0.0          60267

# %%
def lyricist_count(x):
    if x == 'lyricist_missing':
        return 0
    else:
        return sum(map(x.count, ['|', '/', '\\', ';']))+1

def artist_count(x):
    if x == 'lyricist_missing':
        return 0
    else:
        return x.count('and') + x.count(',') + x.count('feat') + x.count('&') + x.count('|') + 1

def composer_count(x):
    if x == 'composer_missing':
        return 0
    else:
        return sum(map(x.count, ['|', '/', '\\', ';']))+1
    
def genre_id_count(x):
    if x == 'genre_missing':
        return 0
    else:
        return x.count('|') + 1

# %%
train['lyricist_count'] = train['lyricist'].apply(lyricist_count)
train['artist_count'] = train['artist_name'].apply(artist_count)
train['composer_count'] = train['composer'].apply(composer_count)
train['genre_count'] = train['genre_ids'].apply(genre_id_count)

# %%
train['isrc_country'] = train.isrc.apply(lambda x: x[:2] if x != 'isrc_missing' else 'country_missing')
train['isrc_year'] = train.isrc.apply(lambda x: x[5:7] if x != 'isrc_missing' else -1)

# %%
train.language.value_counts()
mem = train.memory_usage(index=True).sum()
print("Memory consumed by training set  :   {} MB" .format(mem/ 1024**2))
# Out:
# Memory consumed by training set  :   1519.7012786865234 MB

# %% [markdown]
# #### checking distribution in test and train data

# %%
def dist_comp(col,test,train):
    train_col = pd.DataFrame(train[col].value_counts(normalize = True)).reset_index()
    train_col.rename(columns = {col: 'train'}, inplace = True)
    test_col = pd.DataFrame(test[col].value_counts(normalize = True)).reset_index()
    test_col.rename(columns = {col: 'test'}, inplace = True)
    train_col = train_col.merge(test_col, how = 'outer', on = 'index')

    x = np.arange(len(train_col['index'])) 
    barwidth = 0.35

    _ =  plt.bar(x-barwidth/2, train_col.train, width = barwidth, label = 'train')
    _ =  plt.bar(x+barwidth/2, train_col.test, width = barwidth, label = 'test')
    _ =  plt.xticks(ticks = x, labels = train_col['index'], rotation = 90)
    _ = plt.legend()
    plt.show()

dist_comp('source_type', test, train)
dist_comp('gender', test, train)
dist_comp('source_system_tab', test, train)
dist_comp('source_screen_name', test, train)

# %%
train['duration'] = (train.expiration_date - train.registration_init_time)/np.timedelta64(1, 'D')
train['registration_year'] = train.registration_init_time.dt.year
train['registration_month'] = train.registration_init_time.dt.month
train['registration_day'] = train.registration_init_time.dt.day
train['registration_weekday'] = train.registration_init_time.dt.weekday
train['expiration_year'] = train.expiration_date.dt.year
train['expiration_month'] = train.expiration_date.dt.month
train['expiration_day'] = train.expiration_date.dt.day
train['expiration_weekday'] = train.expiration_date.dt.weekday

train.head()
# Out:
#                                            msno  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
#
#                                         song_id source_system_tab  \
# 0  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=           explore
# 1  bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=        my library
# 2  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=        my library
# 3  2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=        my library
# 4  3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=           explore
#
#     source_screen_name      source_type  target  song_length genre_ids  \
# 0              Explore  online-playlist       1     206471.0       359
# 1  Local playlist more   local-playlist       1     284584.0      1259
# 2  Local playlist more   local-playlist       1     225396.0      1259
# 3  Local playlist more   local-playlist       1     255512.0      1019
# 4              Explore  online-playlist       1     187802.0      1011
#
#        artist_name                                 composer  ... isrc_year  \
# 0         Bastille                     Dan Smith| Mark Crew  ...        16
# 1  Various Artists                         composer_missing  ...        99
# 2              Nas     N. Jones、W. Adams、J. Lordan、D. Ingle  ...        06
# 3         Soundway                            Kwadwo Donkoh  ...        10
# 4      Brett Young  Brett Young| Kelly Archer| Justin Ebach  ...        16
#
#    duration  registration_year  registration_month registration_day  \
# 0    2103.0               2012                   1                2
# 1    2301.0               2011                   5               25
# 2    2301.0               2011                   5               25
# 3    2301.0               2011                   5               25
# 4    2103.0               2012                   1                2
#
#    registration_weekday expiration_year expiration_month expiration_day  \
# 0                     0            2017               10              5
# 1                     2            2017                9             11
# 2                     2            2017                9             11
# 3                     2            2017                9             11
# 4                     0            2017               10              5
#
#   expiration_weekday
# 0                  3
# 1                  0
# 2                  0
# 3                  0
# 4                  3
#
# [5 rows x 35 columns]

# %%
_ = plt.hist(train.duration[(train.duration >= 0)], bins = 50)

# %%
#Converting integer time columns to string so that converting to date becomes easy
test.registration_init_time = test.registration_init_time.astype('str')
test.expiration_date = test.expiration_date.astype('str')

#
test.registration_init_time = pd.to_datetime(test.registration_init_time, infer_datetime_format = True)
test.expiration_date = pd.to_datetime(test.expiration_date, infer_datetime_format = True)

test['duration'] = (test.expiration_date - test.registration_init_time)/np.timedelta64(1, 'D')

# %% [markdown]
# ### Exploratory Analysis

# %%
train['song_freq'] = train.groupby("song_id")["registration_init_time"].rank("dense")

# %%
table = pd.pivot_table(data = train, index = 'song_freq', values = 'song_id', columns = 'target', aggfunc = 'count' )
table = (table.divide(table.sum(axis=1), axis=0))*100

table = table.rename(columns=str).reset_index()
_ = plt.plot(table.song_freq, table['0'])

# %%
train['artist_freq'] = train.groupby("artist_name")["registration_init_time"].rank("dense")

# %%
table = pd.pivot_table(data = train, index = 'artist_freq', values = 'artist_name', columns = 'target', aggfunc = 'count' )
table = (table.divide(table.sum(axis=1), axis=0))*100

table = table.rename(columns=str).reset_index()
_ = plt.plot(table.artist_freq, table['0'])

# %%
train['composer_artist_lyricist'] = ((train.composer == train.lyricist) & (train.composer == train.artist_name) \
                                    & (train.lyricist == train.artist_name)).astype(np.int8)
train['composer_artist'] = ((train.composer == train.artist_name)).astype(np.int8)

# %%
_dict_count_song_played_train = {k: v for k, v in train['song_id'].value_counts().iteritems()}
_dict_count_song_played_test = {k: v for k, v in test['song_id'].value_counts().iteritems()}
def count_song_played(x):
    try:
        return _dict_count_song_played_train[x]
    except KeyError:
        try:
            return _dict_count_song_played_test[x]
        except KeyError:
            return 0
    

train['count_song_played'] = train['song_id'].apply(count_song_played).astype(np.int64)
test['count_song_played'] = test['song_id'].apply(count_song_played).astype(np.int64)

# %%
_dict_count_artist_played_train = {k: v for k, v in train['artist_name'].value_counts().iteritems()}
_dict_count_artist_played_test = {k: v for k, v in test['artist_name'].value_counts().iteritems()}
def count_artist_played(x):
    try:
        return _dict_count_artist_played_train[x]
    except KeyError:
        try:
            return _dict_count_artist_played_test[x]
        except KeyError:
            return 0
    

train['count_artist_played'] = train['artist_name'].apply(count_artist_played).astype(np.int64)
test['count_artist_played'] = test['artist_name'].apply(count_artist_played).astype(np.int64)

# %%
#smoothing = 5
#global_mean = train.target.mean()
#x = train.groupby('composer')['target'].agg(['count', 'mean'])
#counts = x['count']
#means = x['mean']

#x['smoothed_mean'] = (x['count'] * x['mean'] + smoothing*global_mean)/(x['count']+smoothing)
#smooth = (counts * means + smoothing * global_mean) / (counts + smoothing)

#x.drop(["mean", "count"], axis=1, inplace=True)
#x = x.rename(columns=str).reset_index()
#x.set_index('composer', inplace=True)
#y = dict(x)
#train['composer_encoded3'] = train['composer'].map(smooth)

##train['composer_enc'] = train.composer.map(x)
#print(global_mean)
#x.loc['Dan Smith| Mark Crew']
#print(type(x))

# %%
#source = train.source_system_tab + " " + train.source_type + " " + train.source_screen_name
#train['com'] = train.source_system_tab + " " + train.source_type + " " + train.source_screen_name

# %%
#train.com.value_counts()

# %%
#import tensorflow as tf
#from tensorflow.keras.preprocessing.text import Tokenizer
#from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
#tokenizer = Tokenizer(num_words= None)
#tokenizer.fit_on_texts(list(source))
#tokenizer.word_index

# %%
#source = tokenizer.texts_to_sequences(source)
#maxlen = max([len(x) for x in source])
#source = pad_sequences(source, maxlen = maxlen)

# %%
#import gensim.models
#model = gensim.models.Word2Vec(sentences=source)

# %%
#for i, word in enumerate(model.wv.vocab):
#    if i == 10:
#        break
#    print(word)

# %%
#source = train.source_system_tab + "," + train.source_type + "," + train.source_screen_name
#df2 = df1[:10].apply(lambda x: ','.join(x.astype(str)), axis=1)
#df2.head()

# %%
#df_clean = pd.DataFrame({'clean': source})
#df_clean

# %%
#sent = [row.split(',') for row in df_clean['clean']]
#model = gensim.models.Word2Vec(sent, min_count=1,size=30,workers=3, window =3, sg = 0)
#for i, word in enumerate(model.wv.vocab):
#    if i == 10:
#        break
#    print(word)

# %%
#max_features = 5000  # Maximum vocab size.
#max_len = 40  # Sequence length to pad the outputs to.

# Create the layer.
#vectorize_layer = TextVectorization(
#  max_tokens=max_features,
#  output_mode='int',
#  output_sequence_length=max_len)

# %%
mem = train.memory_usage(index=True).sum()
print("Memory consumed by training set  :   {} MB" .format(mem/ 1024**2))
# Out:
# Memory consumed by training set  :   2265.479688644409 MB

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7377418 entries, 0 to 7377417
# Data columns (total 41 columns):
# msno                        object
# song_id                     object
# source_system_tab           object
# source_screen_name          object
# source_type                 object
# target                      int64
# song_length                 float64
# genre_ids                   object
# artist_name                 object
# composer                    object
# lyricist                    object
# language                    float64
# city                        int64
# bd                          int64
# gender                      object
# registered_via              int64
# registration_init_time      datetime64[ns]
# expiration_date             datetime64[ns]
# name                        object
# isrc                        object
# lyricist_count              int64
# artist_count                int64
# composer_count              int64
# genre_count                 int64
# isrc_country                object
# isrc_year                   object
# duration                    float64
# registration_year           int64
# registration_month          int64
# registration_day            int64
# registration_weekday        int64
# expiration_year             int64
# expiration_month            int64
# expiration_day              int64
# expiration_weekday          int64
# song_freq                   float64
# artist_freq                 float64
# composer_artist_lyricist    int8
# composer_artist             int8
# count_song_played           int64
# count_artist_played         int64
# dtypes: datetime64[ns](2), float64(5), int64(18), int8(2), object(14)
# memory usage: 2.2+ GB

# %%
#Plotting existing distribution of Count Variables

fig_dims = (12, 10)
fig, ax = plt.subplots(nrows = 3, ncols = 2,figsize=fig_dims)

#Plot Graphs
sns.distplot(train.lyricist_count,ax=ax[0][0])
sns.distplot(train.artist_count,ax=ax[0][1])
sns.distplot(train.composer_count,ax=ax[1][0])
sns.distplot(train.genre_count,ax=ax[1][1])
sns.distplot(train.duration,ax=ax[2][0])
sns.distplot(train.song_freq,ax=ax[2][1])
#ax[2][0].hist(df_clean.number_outpatient)
#ax[2][1].hist(df_clean.number_emergency)
#ax[3][0].hist(df_clean.number_inpatient)

#Set X axis title
#ax[2][0].set_xlabel('Number Outpatient')
#ax[2][1].set_xlabel('Number Emergency')
#ax[3][0].set_xlabel('Number Inpatient')

#Set y-axis to log scale for better visualization
ax[2][0].set_yscale('log')
ax[0][0].set_yscale('log')
ax[0][1].set_yscale('log')
ax[1][0].set_yscale('log')
ax[2][1].set_yscale('log')
ax[1][1].set_yscale('log')

fig.tight_layout()

# %%
pd.options.display.max_colwidth = 10000
#print(train.composer[(train.composer_count > 100)])
#train.iloc[5874948].composer_count = 1

train.loc[train.composer_count > 100, 'composer_count'] = 1
train.loc[train.composer_count > 25, 'composer_count'] = 10
train.loc[train.composer_count > 24, 'composer_count'] = 0

x = 'Point Break| Adams| B. Adams| B.Adams| Barnett| D. Holmes| D.Barett| D.Barnett| D.Holmes| D.Oliver| G. Stack| G.Stack| G.Stack and J. Newman| G.Trotter| Holmes| J. Newman| J.Newman| NEWMAN| Oliver| Stack| Trotter| and G. Stack'
train.loc[(train.composer_count ==22) & (train.composer == x) , 'composer_count'] = 10

train.loc[(train.composer_count ==22), 'composer_count'] = 21
train.loc[(train.lyricist_count >24), 'lyricist_count'] = 0

y = 'Point Break| Adams| B. Adams| B.Adams| Barnett| D. Holmes| D.Barett| D.Barnett| D.Holmes| D.Oliver| G. Stack| G.Stack| G.Stack and J. Newman| G.Trotter| J. Newman| J.Newman| NEWMAN| Oliver| Stac| Trotter| and G. Stack'
train.loc[(train.lyricist_count ==21) & (train.lyricist == y), 'composer_count'] = 10

train.drop(train[train.duration < 0].index, inplace = True)
train.shape
# Out:
# (7377415, 41)

# %%
#condition_1 = (train.composer.apply(lambda x: ('/' in x) & ('|' in x))) & (train.language == 31) \
#            & (train.composer_count ==3) & (train.composer != 'TEDDY/G-DRAGON| T.O.P') \
#            & (train.composer.apply(lambda x: ~('%' in x) & ~("\"" in x)))
#train.loc[condition_1, 'composer_count'] = 2

#condition_2 = (train.composer.apply(lambda x: ('/' in x) & ('|' in x))) & (train.language == 31) \
#            & (train.composer_count ==4) & (train.composer != 'TEDDY/G-DRAGON| T.O.P') \
#            & (train.composer.apply(lambda x: ~('%' in x) & ~("\"" in x)))
#train.loc[condition_2, 'composer_count'] = 3

# %%
class KFoldTargetEncoderTrain(base.BaseEstimator, base.TransformerMixin):

    def __init__(self, colnames,targetName,smoothing=5,n_fold=5,verbosity=True,discardOriginal_col=False):

        self.colnames = colnames
        self.targetName = targetName
        self.n_fold = n_fold
        self.verbosity = verbosity
        self.discardOriginal_col = discardOriginal_col
        self.smoothing = smoothing

    def fit(self, X, y=None):
        return self


    def transform(self,X):

        assert(type(self.targetName) == str)
        assert(type(self.colnames) == str)
        assert(self.colnames in X.columns)
        assert(self.targetName in X.columns)

        mean_of_target = X[self.targetName].mean()
        
        
        kf = KFold(n_splits = self.n_fold)

        #Naming the column
        col_mean_name = self.colnames + '_' + 'encoded'
        X[col_mean_name] = np.nan

        
        for tr_ind, val_ind in kf.split(X):
            X_tr, X_val = X.iloc[tr_ind], X.iloc[val_ind]
            #print(tr_ind,val_ind) 
              
            enc = X_tr.groupby(self.colnames)[self.targetName].agg(['count', 'mean'])
            counts = enc['count']
            means = enc['mean']
            smooth = (counts * means + self.smoothing * mean_of_target) / (counts + self.smoothing)

            X.loc[X.index[val_ind], col_mean_name] = X_val[self.colnames].map(smooth)

            X[col_mean_name].fillna(mean_of_target, inplace = True)

        if self.verbosity:

            encoded_feature = X[col_mean_name].values
            print('Correlation between the new feature, {} and, {} is {}.'.format(col_mean_name,
                                                                                      self.targetName,
                                                                                      np.corrcoef(X[self.targetName].values, encoded_feature)[0][1]))
        if self.discardOriginal_col:
            X = X.drop(self.colnames, axis=1)
            

        return X

# %%
class KFoldTargetEncoderTest(base.BaseEstimator, base.TransformerMixin):
    
    def __init__(self,train,colNames,encodedName):
        
        self.train = train
        self.colNames = colNames
        self.encodedName = encodedName
        
        
    def fit(self, X, y=None):
        return self

    def transform(self,X):


        mean = self.train[[self.colNames,self.encodedName]].groupby(self.colNames).mean().reset_index() 
        
        dd = {}
        for index, row in mean.iterrows():
            dd[row[self.colNames]] = row[self.encodedName]

        
        X[self.encodedName] = X[self.colNames]
        X = X.replace({self.encodedName: dd})

        return X

# %%
target_encod_col = ['genre_ids', 'composer', 'artist_name', 'lyricist', 'name', 'isrc_country']
train_enc = train
for col in target_encod_col:
    targetc = KFoldTargetEncoderTrain(col,'target',n_fold=5, discardOriginal_col=True )
    train_enc = targetc.fit_transform(train_enc)
# Out:
# Correlation between the new feature, genre_ids_encoded and, target is -0.020212189507638846.
# Correlation between the new feature, composer_encoded and, target is 0.10282641674689831.
# Correlation between the new feature, artist_name_encoded and, target is 0.10598786848430782.
# Correlation between the new feature, lyricist_encoded and, target is 0.07321300876324219.
# Correlation between the new feature, name_encoded and, target is 0.13798480358971243.
# Correlation between the new feature, isrc_country_encoded and, target is -0.045293406024079434.

# %%
drop_col = ['isrc', 'registration_init_time', 'expiration_date', 'song_id']
train_enc = train_enc.drop(drop_col,axis=1)

#Selecting string columns
cat_names = list(train_enc.select_dtypes(include='object').columns)
cat_names_2 = ['language','city','registered_via', 'isrc_year']
cat_names.extend(cat_names_2)

#Converting to categories
train_enc[cat_names] = train_enc[cat_names].astype('category')

int_names = list(train_enc.select_dtypes(include='int64').columns)
train_enc[int_names] = train_enc[int_names].astype('int32')

int_8_col = ['target', 'isrc_year']
train_enc[int_8_col] = train_enc[int_8_col].astype('int8')

float_names = list(train_enc.select_dtypes(include='float64').columns)
train_enc[float_names] = train_enc[float_names].astype('float32')
train_enc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7377415 entries, 0 to 7377417
# Data columns (total 37 columns):
# msno                        category
# source_system_tab           category
# source_screen_name          category
# source_type                 category
# target                      int8
# song_length                 float32
# language                    category
# city                        category
# bd                          int32
# gender                      category
# registered_via              category
# lyricist_count              int32
# artist_count                int32
# composer_count              int32
# genre_count                 int32
# isrc_year                   int8
# duration                    float32
# registration_year           int32
# registration_month          int32
# registration_day            int32
# registration_weekday        int32
# expiration_year             int32
# expiration_month            int32
# expiration_day              int32
# expiration_weekday          int32
# song_freq                   float32
# artist_freq                 float32
# composer_artist_lyricist    int8
# composer_artist             int8
# count_song_played           int32
# count_artist_played         int32
# genre_ids_encoded           float32
# composer_encoded            float32
# artist_name_encoded         float32
# lyricist_encoded            float32
# name_encoded                float32
# isrc_country_encoded        float32
# dtypes: category(8), float32(10), int32(15), int8(4)
# memory usage: 1.1 GB

# %%
mem = train_enc.memory_usage(index=True).sum()
print("Memory consumed by training set  :   {} MB" .format(mem/ 1024**2))
# Out:
# Memory consumed by training set  :   1172.8017263412476 MB

# %%
#train.to_csv('train_cat.csv',index = False)

# %%
train_enc.head()

# %%
#train_enc.to_csv('train_clean.csv',index = False)

# %% [markdown]
# ### SVD Implementation of User-Song Features

# %%
matrix = train.drop(train.columns.difference(['msno','song_id','target']),axis = 1)

n_users = matrix.msno.unique().shape[0]
n_songs = matrix.song_id.unique().shape[0]

users = pd.DataFrame(matrix.msno.unique(), columns = ['msno'])
users['index'] = users.index
users.set_index('msno', inplace = True)
users = users.to_dict()['index']
matrix['msno_index'] =  matrix.msno.map(users)

songs = pd.DataFrame(matrix.song_id.unique(), columns = ['song'])
songs['index'] = songs.index
songs.set_index('song', inplace = True)
songs = songs.to_dict()['index']
matrix['song_index'] =  matrix.song_id.map(songs)

#users = {users.msno: users.index}
matrix= matrix.drop(['msno', 'song_id'], axis = 1)
matrix.head()
# Out:
#    target  msno_index  song_index
# 0       1           0           0
# 1       1           1           1
# 2       1           1           2
# 3       1           1           3
# 4       1           0           4

# %%
from scipy.sparse import csc_matrix
user_song = csc_matrix((matrix.target, (matrix.msno_index, matrix.song_index)),(n_users,n_songs))
user_song
# Out:
# <30754x359966 sparse matrix of type '<class 'numpy.int64'>'
# 	with 7377415 stored elements in Compressed Sparse Column format>

# %%
from sklearn.decomposition import TruncatedSVD
svd = TruncatedSVD(n_components=15, n_iter=7, random_state=42)
svd.fit(user_song)
# Out:
# TruncatedSVD(algorithm='randomized', n_components=15, n_iter=7, random_state=42,
#              tol=0.0)

# %%
print(svd.explained_variance_ratio_.sum())
#print(svd.singular_values_)
# Out:
# 0.15921303546551016

# %%
plt.plot(svd.singular_values_)

# %%
user_song_reduced = svd.transform(user_song)
col_name = ['us_'+str(i) for i in range(1,16)]
user_song_feat = pd.DataFrame(user_song_reduced, columns = col_name)
user_song_feat['msno'] = train.msno.unique()
#train_enc.any()


train_enc = train_enc.merge(user_song_feat, how = 'left', on = 'msno')
train = train.merge(user_song_feat, how = 'left', on = 'msno')
#train_enc.info()

# %%
float_names = list(train_enc.select_dtypes(include='float64').columns)
train_enc[float_names] = train_enc[float_names].astype('float16')
train_enc['duration'] = train_enc['duration'].astype('int32')
train_enc['song_freq'] = train_enc['song_freq'].astype('int32')
#train_enc.drop('msno', axis = 1, inplace = True)
train_enc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7377415 entries, 0 to 7377414
# Data columns (total 52 columns):
# msno                        object
# source_system_tab           category
# source_screen_name          category
# source_type                 category
# target                      int8
# song_length                 float32
# language                    category
# city                        category
# bd                          int32
# gender                      category
# registered_via              category
# lyricist_count              int32
# artist_count                int32
# composer_count              int32
# genre_count                 int32
# isrc_year                   int8
# duration                    int32
# registration_year           int32
# registration_month          int32
# registration_day            int32
# registration_weekday        int32
# expiration_year             int32
# expiration_month            int32
# expiration_day              int32
# expiration_weekday          int32
# song_freq                   int32
# artist_freq                 float32
# composer_artist_lyricist    int8
# composer_artist             int8
# count_song_played           int32
# count_artist_played         int32
# genre_ids_encoded           float32
# composer_encoded            float32
# artist_name_encoded         float32
# lyricist_encoded            float32
# name_encoded                float32
# isrc_country_encoded        float32
# us_1                        float16
# us_2                        float16
# us_3                        float16
# us_4                        float16
# us_5                        float16
# us_6                        float16
# us_7                        float16
# us_8                        float16
# us_9                        float16
# us_10                       float16
# us_11                       float16
# us_12                       float16
# us_13                       float16
# us_14                       float16
# us_15                       float16
# dtypes: category(7), float16(15), float32(8), int32(17), int8(4), object(1)
# memory usage: 1.1+ GB

# %% [markdown]
# ### SVD Implementation of User-genre_id Features

# %%
matrix = train.drop(train.columns.difference(['msno','genre_ids','target']),axis = 1)
matrix = pd.pivot_table(train,values = 'target', index = 'msno', columns = 'genre_ids', aggfunc= np.sum).fillna(0)
user_genre = csc_matrix(matrix)

# %%
svd = TruncatedSVD(n_components=5, n_iter=7, random_state=42)
svd.fit(user_genre)
print(svd.explained_variance_ratio_.sum())
plt.plot(svd.singular_values_)
# Out:
# 0.9679392009596248

# %%
user_genre_reduced = svd.transform(user_genre)
col_name = ['ug_'+str(i) for i in range(1,6)]
user_genre_feat = pd.DataFrame(user_genre_reduced, columns = col_name)
user_genre_feat['msno'] = matrix.index
#train_enc.any()


train_enc = train_enc.merge(user_genre_feat, how = 'left', on = 'msno')
train = train.merge(user_genre_feat, how = 'left', on = 'msno')
#train_enc.info()

# %%
#train_enc.info()

# %% [markdown]
# ### SVD Implementation of User-artist name Features

# %%
matrix = train.drop(train.columns.difference(['msno','artist_name','target']),axis = 1)
#matrix = pd.pivot_table(train,values = 'target', index = 'msno', columns = 'artist_name', aggfunc= np.sum).fillna(0)
matrix = matrix.groupby(['msno', 'artist_name'])['target'].sum()
matrix = matrix.reset_index()

n_users = matrix.msno.unique().shape[0]
n_artist = matrix.artist_name.unique().shape[0]

users = pd.DataFrame(matrix.msno.unique(), columns = ['msno'])
users['index'] = users.index
users.set_index('msno', inplace = True)
users = users.to_dict()['index']
matrix['msno_index'] =  matrix.msno.map(users)

artist = pd.DataFrame(matrix.artist_name.unique(), columns = ['artist'])
artist['index'] = artist.index
artist.set_index('artist', inplace = True)
artist = artist.to_dict()['index']
matrix['artist_index'] =  matrix.artist_name.map(artist)

user_index = matrix.msno.unique()
matrix= matrix.drop(['msno', 'artist_name'], axis = 1)
matrix.head()

#user_genre = csc_matrix(matrix)
#matrix.head()
# Out:
#    target  msno_index  artist_index
# 0       2           0             0
# 1       1           0             1
# 2       0           0             2
# 3       3           0             3
# 4       4           0             4

# %%
user_artist = csc_matrix((matrix.target, (matrix.msno_index, matrix.artist_index)),(n_users,n_artist))

svd = TruncatedSVD(n_components=10, n_iter=7, random_state=42)
svd.fit(user_artist)
print(svd.explained_variance_ratio_.sum())
plt.plot(svd.singular_values_)
# Out:
# 0.43740614136199096

# %%
user_artist_reduced = svd.transform(user_artist)
col_name = ['ua_'+str(i) for i in range(1,11)]
user_artist_feat = pd.DataFrame(user_artist_reduced, columns = col_name)
user_artist_feat['msno'] = user_index
#train_enc.any()


train_enc = train_enc.merge(user_artist_feat, how = 'left', on = 'msno')
train = train.merge(user_artist_feat, how = 'left', on = 'msno')
#train_enc.info()

# %%
float_names = list(train_enc.select_dtypes(include='float64').columns)
train_enc[float_names] = train_enc[float_names].astype('float16')

float_names = list(train_enc.select_dtypes(include='float32').columns)
float_names.remove('song_length')
train_enc[float_names] = train_enc[float_names].astype('float16')
#train_enc.drop('msno', axis = 1, inplace = True)
train_enc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7377415 entries, 0 to 7377414
# Data columns (total 67 columns):
# msno                        object
# source_system_tab           category
# source_screen_name          category
# source_type                 category
# target                      int8
# song_length                 float32
# language                    category
# city                        category
# bd                          int32
# gender                      category
# registered_via              category
# lyricist_count              int32
# artist_count                int32
# composer_count              int32
# genre_count                 int32
# isrc_year                   int8
# duration                    int32
# registration_year           int32
# registration_month          int32
# registration_day            int32
# registration_weekday        int32
# expiration_year             int32
# expiration_month            int32
# expiration_day              int32
# expiration_weekday          int32
# song_freq                   int32
# artist_freq                 float16
# composer_artist_lyricist    int8
# composer_artist             int8
# count_song_played           int32
# count_artist_played         int32
# genre_ids_encoded           float16
# composer_encoded            float16
# artist_name_encoded         float16
# lyricist_encoded            float16
# name_encoded                float16
# isrc_country_encoded        float16
# us_1                        float16
# us_2                        float16
# us_3                        float16
# us_4                        float16
# us_5                        float16
# us_6                        float16
# us_7                        float16
# us_8                        float16
# us_9                        float16
# us_10                       float16
# us_11                       float16
# us_12                       float16
# us_13                       float16
# us_14                       float16
# us_15                       float16
# ug_1                        float16
# ug_2                        float16
# ug_3                        float16
# ug_4                        float16
# ug_5                        float16
# ua_1                        float16
# ua_2                        float16
# ua_3                        float16
# ua_4                        float16
# ua_5                        float16
# ua_6                        float16
# ua_7                        float16
# ua_8                        float16
# ua_9                        float16
# ua_10                       float16
# dtypes: category(7), float16(37), float32(1), int32(17), int8(4), object(1)
# memory usage: 1.2+ GB

# %% [markdown]
# ### SVD Implementation of User- (source_system_tab, source_type, source_screen_name) Features

# %%
mixed_feature = pd.Series(train.source_system_tab + " " + train.source_type + " " + train.source_screen_name, name = 'source')
matrix = pd.concat([train.msno, mixed_feature, train.target], axis = 1)


user_source = pd.pivot_table(matrix,values = 'target', index = 'msno', columns = 'source', aggfunc= np.sum).fillna(0)
#matrix = matrix.groupby(['msno', 'artist_name'])['target'].sum()
#matrix = matrix.reset_index()

#n_users = matrix.msno.unique().shape[0]
#n_source = matrix.source.unique().shape[0]

#user_source.head()

# %%
svd = TruncatedSVD(n_components=3, n_iter=7, random_state=42)
svd.fit(user_source)
print(svd.explained_variance_ratio_.sum())
plt.plot(svd.singular_values_)
# Out:
# 0.8115185935467324

# %%
user_source_reduced = svd.transform(user_source)
col_name = ['usr_'+str(i) for i in range(1,4)]
user_source_feat = pd.DataFrame(user_source_reduced, columns = col_name)
user_source_feat['msno'] = user_source.index
#train_enc.any()


train_enc = train_enc.merge(user_source_feat, how = 'left', on = 'msno')
train = train.merge(user_source_feat, how = 'left', on = 'msno')


#train_enc.info()

# %%
float_names = list(train_enc.select_dtypes(include='float64').columns)
train_enc[float_names] = train_enc[float_names].astype('float16')

# %%
train_enc.to_csv('train_clean.csv',index = False)

# %%
drop_col = ['isrc', 'registration_init_time', 'expiration_date']#, 'song_id', 'msno']
train = train.drop(drop_col,axis=1)

#Selecting string columns
cat_names = list(train.select_dtypes(include='object').columns)
#cat_names_2 = ['language','city','registered_via', 'isrc_year']
#cat_names.extend(cat_names_2)

#Converting to categories
train[cat_names] = train[cat_names].astype('category')

int_names = list(train.select_dtypes(include='int64').columns)
train[int_names] = train[int_names].astype('int16')

int_8_col = ['target', 'isrc_year']
train[int_8_col] = train[int_8_col].astype('uint8')

float_names = list(train.select_dtypes(include='float64').columns)
train[float_names] = train[float_names].astype('float32')
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7377415 entries, 0 to 7377417
# Data columns (total 38 columns):
# msno                        category
# song_id                     category
# source_system_tab           category
# source_screen_name          category
# source_type                 category
# target                      uint8
# song_length                 float32
# genre_ids                   category
# artist_name                 category
# composer                    category
# lyricist                    category
# language                    float32
# city                        int16
# bd                          int16
# gender                      category
# registered_via              int16
# name                        category
# lyricist_count              int16
# artist_count                int16
# composer_count              int16
# genre_count                 int16
# isrc_country                category
# isrc_year                   uint8
# duration                    float32
# registration_year           int16
# registration_month          int16
# registration_day            int16
# registration_weekday        int16
# expiration_year             int16
# expiration_month            int16
# expiration_day              int16
# expiration_weekday          int16
# song_freq                   float32
# artist_freq                 float32
# composer_artist_lyricist    int8
# composer_artist             int8
# count_song_played           int16
# count_artist_played         int16
# dtypes: category(12), float32(5), int16(17), int8(2), uint8(2)
# memory usage: 700.6 MB

# %%
#train.to_csv('train_cat.csv',index = False)
train.to_csv('train_study.csv',index = False)

# %% [markdown]
# ### Cosine Similarity Creation

# %%
from sklearn.cluster import DBSCAaaN
A = matrix.msno_index.to_numpy().reshape(-1,1)
B = matrix.song_index.to_numpy().reshape(-1,1)

X =[[x, y] for x, y in zip(matrix.msno_index, matrix.song_index)]
X = csc_matrix(X)
#X = np.array([[1, 2], [2, 5], [3, 6], [8, 7], [8, 8], [7, 3]])
#Y
clustering = DBSCAN(metric = 'cosine').fit(X)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-62-0e7e80113fa4> in <module>
#       7 #X = np.array([[1, 2], [2, 5], [3, 6], [8, 7], [8, 8], [7, 3]])
#       8 #Y
# ----> 9 clustering = DBSCAN(metric = 'cosine').fit(X)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\_dbscan.py in fit(self, X, y, sample_weight)
#     333         # This has worst case O(n^2) memory complexity
#     334         neighborhoods = neighbors_model.radius_neighbors(X,
# --> 335                                                          return_distance=False)
#     336
#     337         if sample_weight is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_base.py in radius_neighbors(self, X, radius, return_distance, sort_results)
#     946                 results = neigh_dist, neigh_ind
#     947             else:
# --> 948                 neigh_ind_list = sum(chunked_results, [])
#     949                 results = _to_object_array(neigh_ind_list)
#     950
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    1593             X_chunk = X[sl]
#    1594         D_chunk = pairwise_distances(X_chunk, Y, metric=metric,
# -> 1595                                      n_jobs=n_jobs, **kwds)
#    1596         if ((X is Y or Y is None)
#    1597                 and PAIRWISE_DISTANCE_FUNCTIONS.get(metric, None)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, **kwds)
#    1750         func = partial(distance.cdist, metric=metric, **kwds)
#    1751
# -> 1752     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1753
#    1754
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1346
#    1347     if effective_n_jobs(n_jobs) == 1:
# -> 1348         return func(X, Y, **kwds)
#    1349
#    1350     # enforce a threading backend to prevent data communication overhead
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in cosine_distances(X, Y)
#     819     """
#     820     # 1.0 - cosine_similarity(X, Y) without copy
# --> 821     S = cosine_similarity(X, Y)
#     822     S *= -1
#     823     S += 1
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in cosine_similarity(X, Y, dense_output)
#    1174
#    1175     K = safe_sparse_dot(X_normalized, Y_normalized.T,
# -> 1176                         dense_output=dense_output)
#    1177
#    1178     return K
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\extmath.py in safe_sparse_dot(a, b, dense_output)
#     153     if (sparse.issparse(a) and sparse.issparse(b)
#     154             and dense_output and hasattr(ret, "toarray")):
# --> 155         return ret.toarray()
#     156     return ret
#     157
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\sparse\compressed.py in toarray(self, order, out)
#    1023         if out is None and order is None:
#    1024             order = self._swap('cf')[0]
# -> 1025         out = self._process_toarray_args(order, out)
#    1026         if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1027             raise ValueError('Output array must be C or F contiguous')
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\sparse\base.py in _process_toarray_args(self, order, out)
#    1187             return out
#    1188         else:
# -> 1189             return np.zeros(self.shape, dtype=self.dtype, order=order)
#    1190
#    1191
#
# MemoryError:

# %%
matrix.head()

# %%
matrix.shape

# %%
from sklearn.metrics.pairwise import cosine_similarity

X = csc_matrix(matrix.msno_index.to_numpy().reshape(-1,1))
Y =csc_matrix(matrix.song_index.to_numpy().reshape(-1,1))

user_song_cosine = cosine_similarity(X, Y, dense_output=False)

# %%
user_song_cosine
# Out:
# array([[1.        , 0.08630286, 0.11962964, ..., 0.        , 0.02185694,
#         0.        ]])

# %%
#Checking the dsitribution of the data set again
def cosine(s1, s2):
    """Take two pd.Series objects and return their cosine similarity."""
    return np.sum(s1 * s2) / np.sqrt(np.sum(s1 ** 2) * np.sum(s2 ** 2))

# %%
cosine(1, 0.5)
# Out:
# 1.0

# %%
#user_song_cosine2 = cosine(matrix.msno_index, matrix)
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
vec1 = np.array([1,1,0,1,1])
vec2 = np.array([0,1,0,1,1])
print(cosine_similarity([vec1, vec2]))
#print(cosine_similarity(vec1, vec2))
# Out:
# [[1.        0.8660254]
#  [0.8660254 1.       ]]

# %%
print(user_song_cosine2)
# Out:
# 503656.22281171737

# %%
documents = (
"The sky is blue",
"The sun is bright",
"The sun in the sky is bright",
"We can see the shining sun, the bright sun"
)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(documents)
tfidf_matrix.shape
# Out:
# (4, 11)

# %%
print(tfidf_matrix)
from sklearn.metrics.pairwise import cosine_similarity
cosine_similarity(tfidf_matrix[0:1], tfidf_matrix)
# Out:
#   (0, 0)	0.6591911178676787
#   (0, 4)	0.42075315164463567
#   (0, 7)	0.5197138488789809
#   (0, 9)	0.3439932714296342
#   (1, 1)	0.5221086219944969
#   (1, 8)	0.5221086219944969
#   (1, 4)	0.5221086219944969
#   (1, 9)	0.42685800978431027
#   (2, 3)	0.5042345768555538
#   (2, 1)	0.32184639875982174
#   (2, 8)	0.32184639875982174
#   (2, 4)	0.32184639875982174
#   (2, 7)	0.3975443320946988
#   (2, 9)	0.5262610401109715
#   (3, 6)	0.37459947122408604
#   (3, 5)	0.37459947122408604
#   (3, 2)	0.37459947122408604
#   (3, 10)	0.37459947122408604
#   (3, 1)	0.2391019900750339
#   (3, 8)	0.4782039801500678
#   (3, 9)	0.39096308821336656
# array([[1.        , 0.36651513, 0.52305744, 0.13448867]])

# %% [markdown]
# ### Exploratory Data Analysis

# %%
#Setting Figure Size
figsize(7,7)

#Exploring Hospital Readmission Rates
readm_rate = pd.DataFrame(df_clean2.groupby('readmitted').size())
readm_rate = readm_rate.unstack(0)
readm_rate = pd.DataFrame(readm_rate, columns = ['Readmission Rates'])
readm_rate = readm_rate.droplevel(level = 0)

#Plotting a pie chart
_ = readm_rate.plot(y = readm_rate.columns, kind='pie',autopct='%1.1f%%')

# %% [markdown]
# #### It is expected that readmission rates would change with each vist number for patients.

# %%
df_clean2 = df_clean
#Setting Figure Size
figsize(10,7)

#Visualizing relation between Visit Number and readmission rates
visit = df_clean2.groupby(['visit_num','readmitted']).size()
visit = visit.unstack(1)

#Normalizing 
visit = visit.divide(visit.sum(axis=1), axis=0)*100

#Plotting line graph
_ = visit.plot()
_ = plt.ylabel('Readmission Rates')
plt.tight_layout()

# %% [markdown]
# #### Understanding the 21 feature of Medicines, Glucose serum test and A1Cresult

# %%
#Creating a separate data frame of medicines and tests
medicines = ['max_glu_serum','A1Cresult','metformin','repaglinide','nateglinide','chlorpropamide','glimepiride','acetohexamide','glipizide','glyburide',
             'tolbutamide','pioglitazone','rosiglitazone','acarbose','miglitol','troglitazone','tolazamide','insulin',
             'glyburide-metformin','glipizide-metformin','glimepiride-pioglitazone','metformin-rosiglitazone',
             'metformin-pioglitazone','readmitted']
df_med = df_clean2[medicines]

# %%
# Grouping max_glu_serum and Readmitted Columns
glu_serum = df_med.groupby(['max_glu_serum','readmitted']).size().unstack()

#Normalizing i.e Calculating %Readmission
glu_serum = (glu_serum.divide(glu_serum.sum(axis=1), axis=0))*100

#Renaming the column index from category to string and sorting based on %
glu_serum = glu_serum.rename(columns=str).reset_index()
glu_serum.sort_values('<30',ascending = False, inplace = True)

#Setting Figure size and plotting the bar chart
fig_dims = (7, 5)
fig, ax = plt.subplots(figsize=fig_dims)
sns.barplot(data = glu_serum, x = 'max_glu_serum',y='<30', ax = ax, order = glu_serum['max_glu_serum'])
plt.ylabel('Radmission rates (<30)')
plt.tight_layout()

# %%
figsize(5,5)
# Grouping A1CResult and Readmitted Columns
ac = df_med.groupby(['A1Cresult','readmitted']).size().unstack()

#Normalizing i.e. Calculating %Readmission
ac= (ac.divide(ac.sum(axis=1), axis=0))*100

#Renaming the column index from category to string
ac = ac.rename(columns=str).reset_index()
ac.sort_values('<30',ascending = False, inplace = True)

#Setting Figure size and plotting the bar chart
fig_dims = (7, 5)
fig, ax = plt.subplots(figsize=fig_dims)
sns.barplot(data = ac, x = 'A1Cresult',y='<30', ax = ax, order = ac['A1Cresult'])
plt.ylabel('Radmission rates (<30)')
plt.tight_layout()

# %%
#Grouping change of medications and Readmitted.
change = df_clean2.groupby(['change','readmitted']).size().unstack()

#Normalizing
change = (change.divide(change.sum(axis=1), axis=0))*100

#Renaming the column index from category to string
change = change.rename(columns=str).reset_index()
change.sort_values('<30',ascending = False, inplace = True)

#Plotting the bar Graph
figsize(7,5)
sns.barplot(data = change, x = 'change',y='<30', order = change['change'])
plt.ylabel('Radmission rates (<30)')
plt.xlabel('Change of Medicines (change)')
plt.tight_layout()

# %%
#Extracting 21 features of medicines
med = pd.DataFrame()
x = df_med.drop(['max_glu_serum','A1Cresult','readmitted'], axis = 1)
for col in x.columns:
    med_s = df_med[col].value_counts()
    med = pd.concat([med,med_s],axis = 1) 
med = pd.DataFrame(med.stack())
med = med.unstack(0)
med.columns = med.columns.droplevel(0)
med.sort_values('No',inplace = True, ascending = False)

#Normalizing
med = med.divide(med.sum(axis=1), axis=0)*100

#Plotting the graph
figsize(10,7)
_ = plt.plot(med)
_ = plt.xticks(rotation=90) 
_ = plt.legend(labels = med.columns, loc = 'center left')
_ = plt.axvline(x='tolazamide', color='b', linestyle='dashed', linewidth=1)
_ = plt.ylabel('% of Total Patients')
plt.tight_layout()

# %% [markdown]
# #### From the above graph we see that there are few medicines, that were not prescribed and not much change were prescribed to their dosage. Using this medicines in our model will have no impact in our results. So it would be best to drop them. Dropping medicines till tolazamide

# %%
#Dropping medicines that are not relevant
med_drop = ['acetohexamide','tolbutamide','miglitol','troglitazone','tolazamide','glimepiride-pioglitazone',
            'metformin-rosiglitazone', 'metformin-pioglitazone', 'glipizide-metformin']
df_clean2 = df_clean2.drop(med_drop,axis=1)
df_clean2.shape
# Out:
# (100110, 35)

# %% [markdown]
# #### Understanding Patient Characteristics of the data set and its relation with the Readmission rates

# %%
#Extracting relevant Features
age_d = pd.DataFrame(df_clean2.groupby(['age']).size(), columns = ['count'])
race_d = pd.DataFrame(df_clean2.groupby(['race']).size(), columns = ['count'])
gen_d = pd.DataFrame(df_clean2.groupby(['gender']).size(), columns = ['count'])

fig_dims = (12, 12)
fig, axis = plt.subplots(nrows = 2, ncols = 2, figsize=fig_dims)

#Plotting the pie chart to see distribution of categories
axis[0,0].pie(age_d, labels = age_d.index, autopct='%1.1f%%')
axis[0,1].pie(race_d, labels = race_d.index, autopct='%1.1f%%')
axis[1,0].pie(gen_d, labels = gen_d.index, autopct='%1.1f%%')

plt.tight_layout()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   # Remove the CWD from sys.path while we load stuff.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   # This is added back by InteractiveShellApp.init_path()
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   if sys.path[0] == '':

# %% [markdown]
# #### Checking the Distribution of Race for <30 category of Readmission. Caucasian Race has higher chance of readmission.

# %%
#Grouping Race and Readmitted.
race = df_clean2.groupby(['race','readmitted']).size().unstack()

#Normalizing
race = race.divide(race.sum(axis=1), axis=0)*100

#Renaming the column index from category to string
race = race.rename(columns=str).reset_index()
race.sort_values('<30',ascending = False, inplace = True)

#Plotting the bar Graph
figsize(7,5)
_ = sns.barplot(data = race, x = 'race',y='<30', order = race['race'])
_ = plt.xticks(rotation=60) 
_ = plt.ylabel('Readmission Rate % (<30)')

# %% [markdown]
# #### Distribution of Age for <30 category of Readmission. Patient with >40 age have high chances of getting readmitted.

# %%
# Grouping Age and Readmitted Columns
age = df_clean2.groupby(['age','readmitted']).size().unstack()

#Normalizing
age = age.divide(age.sum(axis=1), axis=0)*100

#Renaming the column index from category to string
age = age.rename(columns=str).reset_index()
age.sort_values('<30',ascending = False, inplace = True)

#Setting Figure size and plotting the bar chart
fig_dims = (10, 7)
fig, ax = plt.subplots(figsize=fig_dims)
_ = sns.barplot(data = age, x = 'age',y='<30', ax = ax, order = age['age'])
_ = plt.ylabel('Readmission Rate % (<30)')

# %% [markdown]
# #### Distribution of Gender and Readmission Rates

# %%
# Grouping gender and Readmitted Columns
gender = df_clean2.groupby(['gender','readmitted']).size().unstack()

#Normalizing
gender = gender.divide(gender.sum(axis=1), axis=0)*100

#Renaming the column index from category to string
gender = gender.rename(columns=str).reset_index()
gender.sort_values('<30',ascending = False, inplace = True)

#Setting Figure size and plotting the bar chart
fig_dims = (7, 5)
fig, ax = plt.subplots(figsize=fig_dims)
_ = sns.barplot(data = gender, x = 'gender',y='<30', ax = ax, order = gender['gender'])
_ = plt.ylabel('Readmission Rate % (<30)')

# %% [markdown]
# #### Distribution of admission and Discharge features shows that, emergency patients have high chances of getting admitted (ID 7 and 1 represents emergency). Patient getting discharge and going home have lower chances of readmission

# %%
# Grouping Discharge Disposition and Readmitted Columns
dis = df_clean2.groupby(['discharge_disposition_id','readmitted']).size().unstack()

#Normalizing
dis = dis.divide(dis.sum(axis=1), axis=0)*100

#Renaming the column index from category to string
dis = dis.rename(columns=str).reset_index()
dis.sort_values('<30',ascending = False, inplace = True)

#Setting Figure size and plotting the bar chart
fig_dims = (7, 5)
fig, ax = plt.subplots(figsize=fig_dims)
_ = sns.barplot(data = dis, x = 'discharge_disposition_id',y='<30', ax = ax, order = dis['discharge_disposition_id'])
_ = plt.ylabel('Readmission Rate % (<30)')

# %%
# Grouping Admission type and source and Readmitted Columns
adm_type = df_clean2.groupby(['admission_type_id','readmitted']).size().unstack()
adm_so = df_clean2.groupby(['admission_source_id','readmitted']).size().unstack()

#Normalizing
adm_type = adm_type.divide(adm_type.sum(axis=1), axis=0)*100
adm_so = adm_so.divide(adm_so.sum(axis=1), axis=0)*100

#Renaming the column index from category to string
adm_type = adm_type.rename(columns=str).reset_index()
adm_so = adm_so.rename(columns=str).reset_index()
adm_type.sort_values('<30',ascending = False, inplace = True)
adm_so.sort_values('<30',ascending = False, inplace = True)

#Setting Figure size and plotting the bar chart
fig_dims = (12, 5)
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize=fig_dims)
sns.barplot(data = adm_type, x = 'admission_type_id',y='<30', ax = ax[0], order = adm_type['admission_type_id'])
sns.barplot(data = adm_so, x = 'admission_source_id',y='<30', ax = ax[1], order = adm_so['admission_source_id'])

ax[0].set_ylabel('Readmission Rate % (<30)')
ax[1].set_ylabel('Readmission Rate % (<30)')
plt.tight_layout()

# %% [markdown]
# #### Determining relation between readmission rates and daignosis features

# %%
## Grouping all diag columns
diag = pd.DataFrame(df_clean2.groupby(['diag_1']).size(), columns = ['diag1'])
cer2 = dict(df_clean2.groupby(['diag_2']).size(), columns = ['d2'])
cer3 = dict(df_clean2.groupby(['diag_3']).size(), columns = ['d3'])

diag = diag.rename(columns=str).reset_index()

diag['diag2'] = diag.diag_1.map(cer2)
diag['diag3'] = diag.diag_1.map(cer3)
diag = pd.melt(diag, id_vars = ['diag_1'],value_vars = ['diag1','diag2','diag3']).reset_index()

#Plotting the distribution of diagnosis for diag1,diag2 and diag3
fig_dims = (14, 5)
fig, ax = plt.subplots(figsize=fig_dims)

chart = sns.barplot(data = diag, x = 'diag_1',y='value', hue = 'variable' )
chart.set_xticklabels(chart.get_xticklabels(), rotation=60)
ax.set_ylabel('Number of Patients')
plt.tight_layout()

# %%
#Plotting realation between each diag column and readmission rate
diag_col = [(0,'diag_1'),(1,'diag_2'),(2,'diag_3')]

fig_dims = (15, 5)
fig, ax = plt.subplots(nrows = 1, ncols = 3, figsize=fig_dims)

for i,col in diag_col:
    #Grouping Columns
    diag = df_clean.groupby([col, 'readmitted']).size().unstack()
    
    #Normalizing
    diag = diag.divide(diag.sum(axis=1), axis=0)*100
    
    #Renaming the column index from category to string
    diag = diag.rename(columns=str).reset_index()
    diag.sort_values('<30',ascending = False, inplace = True)
    
    #Plotting the bar graphs
    chart = sns.barplot(data = diag, x = col ,order = diag[col], y='<30', ax = ax[i])#, hue = diag[col])
    chart.set_xticklabels(chart.get_xticklabels(), rotation=60)
    ax[i].set_ylabel('Readmission Rate % (<30)')
    plt.tight_layout()

# %% [markdown]
# #### Visually exploring to see which numeric variables show difference in distribution readmission (<30) and no readmission (>30, NO)

# %%
#Checking the distribution of the data set again
figsize(12,10)
 
#Condition whether the readmission is <30 or not
condition1 = df_clean2.readmitted == '<30'

#Selecting only Numeric columns from the df_clean2
df_numeric = df_clean2.select_dtypes(include='int64')
numeric_col = df_numeric.columns

#Making bin size equal to number of unique values in the columns 
bins = [ len(df_numeric.iloc[:,i].unique()) for i in range(len(numeric_col))]

x = [1,2,3,4,5,6,7,8]

#For Loop to plot graphs for all the features together
for i in range(4):
    plt.subplot(4,2, x[2*i])
    plt.title(numeric_col[2*i])
    plt.hist(df_numeric[condition1].iloc[:,2*i],bins = bins[2*i], alpha = 0.5, label='1', density = True, histtype = 'stepfilled')
    plt.hist(df_numeric[~condition1].iloc[:,2*i],bins = bins[2*i], alpha = 0.5, label='0', density = True, histtype = 'stepfilled')
    #plt.hist(df_numeric[condition3].iloc[:,2*i],bins = bins[2*i], alpha = 0.5, label='NO', density = True, histtype = 'stepfilled')
    if((numeric_col[2*i] == 'number_inpatient') | (numeric_col[2*i] == 'number_outpatient') | 
       (numeric_col[2*i] == 'number_emergency')):
        plt.yscale('log')
    plt.legend()

    plt.subplot(4,2, x[2*i + 1])
    plt.title(numeric_col[2*i + 1])
    plt.hist(df_numeric[condition1].iloc[:,2*i + 1],bins = bins[2*i + 1], alpha = 0.5, label='1', density = True, histtype = 'stepfilled')
    plt.hist(df_numeric[~condition1].iloc[:,2*i + 1],bins = bins[2*i + 1], alpha = 0.5, label='0', density = True, histtype = 'stepfilled')
    #plt.hist(df_numeric[condition3].iloc[:,2*i + 1],bins = bins[2*i + 1], alpha = 0.5, label='NO', density = True, histtype = 'stepfilled')
    if((numeric_col[2*i+1] == 'number_inpatient') | (numeric_col[2*i] == 'number_outpatient') | (numeric_col[2*i] == 'number_emergency')):
        plt.yscale('log')    
    if(numeric_col[2*i+1] == 'number_diagnoses'):
        plt.legend(loc = 'upper left')
    else:
        plt.legend()
    
plt.tight_layout()

# %% [markdown]
# #### Above charts shows that except for num_procedures and number_outpatient all variables are correlated to readmission rates. For readmission, the distribution shifts towards the right. We will use now some statistics to prove our new finding

# %% [markdown]
# #### Using Bootstrapped Hypothesis Test to determine statistical signification for above features

# %%
# Defining Functions for Bootstrapping

np.random.seed(47)
N_rep = 20000

def bootstrap_replicate_1d(data, func):
    """Generate bootstrap replicate of 1D data."""
    bs_sample = np.random.choice(data, len(data))
    return func(bs_sample)


def draw_bs_reps(data, func, size=1):
    """Draw bootstrap replicates."""

    # Initialize array of replicates: bs_replicates
    bs_replicates = np.empty(size)

    # Generate replicates
    for i in range(size):
        bs_replicates[i] = bootstrap_replicate_1d(data,func)
    
    return bs_replicates

# %%
# %%time
#Defining our test statistics 
reps_diff_of_mean = pd.DataFrame(columns = numeric_col)
obs_diff_of_mean = np.empty(shape = 8)

#Loop to calculate P-value for each columns
for i in range(8):
    #Sample for Readmission
    s1 = df_numeric[condition1].iloc[:,i]
    n1 = len(s1)
    
    #Sample for Non-Readmission
    s0 = df_numeric[~condition1].iloc[:,i]
    n0 = len(s0)

    #Calculating overall mean of the column
    combined_mean = np.mean(df_numeric.iloc[:,i])
    
    #Observed difference of mean between two samples
    obs_diff_of_mean[i] = np.mean(s1) - np.mean(s0)

    #Shifting the data for Bootstrapping
    shifted_0 = s0+combined_mean-np.mean(s0)
    shifted_1 = s1+combined_mean-np.mean(s1)

    #Calculating bootstrap replicates
    bs_reps_0 = draw_bs_reps(shifted_0,np.mean,size = N_rep)
    bs_reps_1 = draw_bs_reps(shifted_1,np.mean,size = N_rep)

    #Calculating difference of means for replicates
    reps_diff_of_mean.iloc[:,i] = bs_reps_1 - bs_reps_0
    
    #Calculating p-value
    if obs_diff_of_mean[i] >0:
        p = np.sum(reps_diff_of_mean.iloc[:,i] >= obs_diff_of_mean[i]) / len(reps_diff_of_mean.iloc[:,i])
    else:
        p = np.sum(reps_diff_of_mean.iloc[:,i] <= obs_diff_of_mean[i]) / len(reps_diff_of_mean.iloc[:,i])
    
    print(numeric_col[i], ' p-value =', p*2)
# Out:
# time_in_hospital  p-value = 0.0
# num_lab_procedures  p-value = 0.0
# num_procedures  p-value = 0.0009
# num_medications  p-value = 0.0
# number_outpatient  p-value = 0.0
# number_emergency  p-value = 0.0
# number_inpatient  p-value = 0.0
# number_diagnoses  p-value = 0.0
# Wall time: 4min 40s

# %%
figsize(12,10)

#Plotting the above results graphically
for i in range(4):
    plt.subplot(4,2, x[2*i])
    plt.title(numeric_col[2*i])
    plt.hist(reps_diff_of_mean.iloc[:,2*i], bins = 50, histtype='step')
    plt.axvline(x=obs_diff_of_mean[2*i], color='r', linestyle='dashed', linewidth=1)
    plt.axvline(x=-obs_diff_of_mean[2*i], color='r', linestyle='dashed', linewidth=1)
    
    plt.subplot(4,2, x[2*i + 1])
    plt.title(numeric_col[2*i + 1])
    plt.hist(reps_diff_of_mean.iloc[:,2*i + 1], bins = 50, histtype='step')
    plt.axvline(x=obs_diff_of_mean[2*i + 1], color='r', linestyle='dashed', linewidth=1)
    plt.axvline(x=-obs_diff_of_mean[2*i + 1], color='r', linestyle='dashed', linewidth=1)
    
plt.tight_layout()

# %% [markdown]
# #### Performing Chi-square tests on 21 features of Medicines and dependent variable i.e readmitted

# %%
#Extracting Column Names
cols = df_med.iloc[:,0:23].columns


#Creating data frame to store results of Chi-Square test for all columns
result = pd.DataFrame(columns = ['Feature','Chi2','Test_stat','Degrees of Freedom'])
result['Feature'] = cols
result = result.set_index('Feature')

#Performing Chi-Square Test for all medicing columns using for loop
for col in cols:
    #Building Contigency Table
    contingency_table = pd.crosstab(df_med.readmitted,df_med[col])
    #print(contingency_table)
    i = contingency_table.shape[1]
    #Converting Contigency Table to array
    f_obs = np.array([contingency_table.iloc[0][0:i].values,
                      contingency_table.iloc[1][0:i].values])
                      #contingency_table.iloc[2][0:i].values])
    #Storing the results
    result['Chi2'].loc[col] = round(stats.chi2_contingency(f_obs)[0],3)
    result['Test_stat'].loc[col] = round(stats.chi2_contingency(f_obs)[1],4)
    result['Degrees of Freedom'].loc[col] = stats.chi2_contingency(f_obs)[2]


result.sort_values('Test_stat',ascending = False, inplace = True)
result
# Out:
#                              Chi2 Test_stat  Degrees of Freedom
# Feature
# metformin-pioglitazone      0.004    0.9497                   1
# glimepiride-pioglitazone    0.004    0.9497                   1
# acetohexamide               0.004    0.9497                   1
# troglitazone                0.012    0.9129                   1
# nateglinide                 1.744    0.6272                   3
# tolbutamide                 0.343    0.5583                   1
# metformin-rosiglitazone     0.383    0.5357                   1
# glipizide-metformin         0.614    0.4334                   1
# glimepiride                 3.309    0.3465                   3
# chlorpropamide              4.422    0.2194                   3
# tolazamide                  4.695    0.0956                   2
# glyburide-metformin         7.066    0.0698                   3
# glyburide                   7.118    0.0682                   3
# miglitol                    7.247    0.0644                   3
# pioglitazone               11.649    0.0087                   3
# acarbose                   20.193    0.0002                   3
# rosiglitazone              22.749         0                   3
# insulin                   500.352         0                   3
# A1Cresult                  67.581         0                   3
# glipizide                  33.029         0                   3
# repaglinide                47.883         0                   3
# metformin                 119.147         0                   3
# max_glu_serum              66.616         0                   3

# %% [markdown]
# ### Understanding Multi-Collinearity in the independent variables

# %% [markdown]
# #### 1) Patient Encounter Variables

# %%
figsize(15,15)

#Plotting box plots without whiskers between various numeric variables
plt.subplot(4,2,1)
sns.boxplot(data = df_clean2, x = 'time_in_hospital', y = 'num_lab_procedures', whis = 0, showfliers=False)

plt.subplot(4,2,2)
sns.boxplot(data = df_clean2, x = 'time_in_hospital', y = 'num_medications',whis = 0, showfliers=False)

plt.subplot(4,2,3)
sns.boxplot(data = df_clean2, x = 'time_in_hospital', y = 'number_diagnoses',whis = 0, showfliers=False)

plt.subplot(4,2,4)
sns.boxplot(data = df_clean2, x = 'num_lab_procedures', y = 'num_medications',whis = 0, showfliers=False)
plt.xticks(ticks = [])
# Out:
# ([], <a list of 0 Text xticklabel objects>)

# %%
#Verifing the above visual results using Pearson Correlation
y = np.cov(df_clean2.time_in_hospital,df_clean2.num_lab_procedures)
corr, _ = stats.pearsonr(df_clean2.num_medications,df_clean2.time_in_hospital)
print(corr)
# Out:
# 0.4640878470768858

# %% [markdown]
# #### 2) Patient Admission and discharge Variables

# %%
#Building Contigency Table to check multi-collinearity between discharge disposition and admission_type
contingency_table = pd.crosstab(df_clean2.discharge_disposition_id,df_clean2.admission_type_id)
i = contingency_table.shape[1]
#Converting Contigency Table to array
f_obs = np.array([contingency_table.iloc[0][0:i].values,
                  contingency_table.iloc[1][0:i].values,
                  contingency_table.iloc[2][0:i].values,
                  contingency_table.iloc[3][0:i].values,
                  contingency_table.iloc[4][0:i].values])
#Storing the results
stats.chi2_contingency(f_obs)[0:3]
# Out:
# (1999.093880090593, 0.0, 12)

# %% [markdown]
# #### 3) Multi-Collinearity between medicine features and change columns

# %%
#Extracting Column Names
cols = df_med.iloc[:,0:23].columns

#Creating data frame to store results of Chi-Square test for all columns
result = pd.DataFrame(columns = ['Feature','Chi2','Test_stat','Degrees of Freedom'])
result['Feature'] = cols
result = result.set_index('Feature')

#Performing Chi-Square Test for all medicing columns using for loop
for col in cols:
    #Building Contigency Table
    contingency_table = pd.crosstab(df_clean2.change,df_med[col])
    i = contingency_table.shape[1]
    #Converting Contigency Table to array
    f_obs = np.array([contingency_table.iloc[0][0:i].values,
                      contingency_table.iloc[1][0:i].values])
    #Storing the results
    result['Chi2'].loc[col] = round(stats.chi2_contingency(f_obs)[0],3)
    result['Test_stat'].loc[col] = round(stats.chi2_contingency(f_obs)[1],4)
    result['Degrees of Freedom'].loc[col] = stats.chi2_contingency(f_obs)[2]


result.sort_values('Test_stat',ascending = False, inplace = True)
result
# Out:
# max_glu_serum  >200  >300   None  Norm
# change
# Ch              743   746  44126   826
# No              697   465  50760  1747
# A1Cresult    >7    >8   None  Norm
# change
# Ch         1925  5315  37014  2187
# No         1859  2836  46220  2754
# metformin  Down     No  Steady    Up
# change
# Ch          575  30743   14056  1067
# No            0  49470    4199     0
# repaglinide  Down     No  Steady   Up
# change
# Ch             45  45269    1018  109
# No              0  53314     355    0
# nateglinide  Down     No  Steady  Up
# change
# Ch             11  45894     512  24
# No              0  53521     148   0
# chlorpropamide  Down     No  Steady  Up
# change
# Ch                 1  46411      23   6
# No                 0  53614      55   0
# glimepiride  Down     No  Steady   Up
# change
# Ch            193  42522    3402  324
# No              0  52441    1228    0
# acetohexamide     No  Steady
# change
# Ch             46440       1
# No             53669       0
# glipizide  Down     No  Steady   Up
# change
# Ch          554  37326    7794  767
# No            0  50180    3489    0
# glyburide  Down     No  Steady   Up
# change
# Ch          561  38813    6261  806
# No            0  50730    2939    0
# tolbutamide     No  Steady
# change
# Ch           46431      10
# No           53658      11
# pioglitazone  Down     No  Steady   Up
# change
# Ch             117  40446    5648  230
# No               0  52384    1285    0
# rosiglitazone  Down     No  Steady   Up
# change
# Ch               86  41126    5056  173
# No                0  52656    1013    0
# acarbose  Down     No  Steady  Up
# change
# Ch           3  46171     257  10
# No           0  53632      37   0
# miglitol  Down     No  Steady  Up
# change
# Ch           5  46409      25   2
# No           0  53663       6   0
# troglitazone     No  Steady
# change
# Ch            46438       3
# No            53669       0
# tolazamide     No  Steady  Up
# change
# Ch          46421      19   1
# No          53650      19   0
# insulin   Down     No  Steady     Up
# change
# Ch       12012   8852   14486  11091
# No           0  37824   15845      0
# glyburide-metformin  Down     No  Steady  Up
# change
# Ch                      6  45941     486   8
# No                      0  53471     198   0
# glipizide-metformin     No  Steady
# change
# Ch                   46430      11
# No                   53667       2
# glimepiride-pioglitazone     No  Steady
# change
# Ch                        46440       1
# No                        53669       0
# metformin-rosiglitazone     No  Steady
# change
# Ch                       46439       2
# No                       53669       0
# metformin-pioglitazone     No  Steady
# change
# Ch                      46440       1
# No                      53669       0
#                              Chi2 Test_stat  Degrees of Freedom
# Feature
# metformin-pioglitazone      0.005    0.9423                   1
# glimepiride-pioglitazone    0.005    0.9423                   1
# acetohexamide               0.005    0.9423                   1
# tolbutamide                 0.011    0.9157                   1
# tolazamide                  1.355    0.5079                   2
# metformin-rosiglitazone     0.658    0.4172                   1
# troglitazone                1.646    0.1994                   1
# glipizide-metformin         6.179    0.0129                   1
# chlorpropamide             17.054    0.0007                   3
# acarbose                  214.643         0                   3
# glyburide-metformin       184.723         0                   3
# insulin                     40838         0                   3
# miglitol                   22.724         0                   3
# max_glu_serum             340.069         0                   3
# rosiglitazone             3868.19         0                   3
# A1Cresult                 1323.42         0                   3
# glyburide                 3649.69         0                   3
# glipizide                 4352.55         0                   3
# glimepiride               2062.73         0                   3
# nateglinide               300.587         0                   3
# repaglinide                   612         0                   3
# metformin                 10871.3         0                   3
# pioglitazone              4127.56         0                   3

# %%
df_vif = df_clean2#.drop('readmitted', axis=1)
corr_matrix = df_vif.corr()

# %%
figsize(12,9)
_ = sns.heatmap(corr_matrix, center = 0, annot=True)

# %%
df_clean2.shape
# Out:
# (100110, 44)

# %%
df_clean2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96551 entries, 0 to 101765
# Data columns (total 35 columns):
# race                        96551 non-null category
# gender                      96551 non-null category
# age                         96551 non-null category
# admission_type_id           96551 non-null category
# discharge_disposition_id    96551 non-null category
# admission_source_id         96551 non-null category
# time_in_hospital            96551 non-null int64
# num_lab_procedures          96551 non-null int64
# num_procedures              96551 non-null int64
# num_medications             96551 non-null int64
# number_outpatient           96551 non-null int64
# number_emergency            96551 non-null int64
# number_inpatient            96551 non-null int64
# diag_1                      96551 non-null category
# diag_2                      96551 non-null category
# diag_3                      96551 non-null category
# number_diagnoses            96551 non-null int64
# max_glu_serum               96551 non-null category
# A1Cresult                   96551 non-null category
# metformin                   96551 non-null category
# repaglinide                 96551 non-null category
# nateglinide                 96551 non-null category
# chlorpropamide              96551 non-null category
# glimepiride                 96551 non-null category
# glipizide                   96551 non-null category
# glyburide                   96551 non-null category
# pioglitazone                96551 non-null category
# rosiglitazone               96551 non-null category
# acarbose                    96551 non-null category
# insulin                     96551 non-null category
# glyburide-metformin         96551 non-null category
# change                      96551 non-null category
# diabetesMed                 96551 non-null category
# readmitted                  96551 non-null category
# visit_num                   96551 non-null category
# dtypes: category(27), int64(8)
# memory usage: 11.6 MB

# %%
#Encoding Age. To retain the ordinal nature of age 
age_dict = {'[70-80)': 75,'[80-90)': 85, '[90-100)':100, '[60-70)': 65, '[50-60)': 55, '[40-50)': 45, '[30-40)':35,
           '[20-30)': 25, '[10-20)': 15, '[0-10)': 5}
df_clean.age = df_clean.age.map(age_dict)

#Visit_num Encoding as Number. '>3' was considered as 4 for simplification purposes
visit_num_dict = {'1.0': 1, '2.0': 2, '3.0': 3, '>3': 4}
df_clean.visit_num = df_clean.visit_num.map(visit_num_dict)

# %%
df_numeric_1 = df_clean.select_dtypes(exclude = 'category')
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100110 entries, 0 to 101765
# Data columns (total 44 columns):
# race                        100110 non-null category
# gender                      100110 non-null category
# age                         0 non-null float64
# admission_type_id           100110 non-null category
# discharge_disposition_id    100110 non-null category
# admission_source_id         100110 non-null category
# time_in_hospital            100110 non-null int64
# num_lab_procedures          100110 non-null int64
# num_procedures              100110 non-null int64
# num_medications             100110 non-null int64
# number_outpatient           100110 non-null int64
# number_emergency            100110 non-null int64
# number_inpatient            100110 non-null int64
# diag_1                      100110 non-null category
# diag_2                      100110 non-null category
# diag_3                      100110 non-null category
# number_diagnoses            100110 non-null int64
# max_glu_serum               100110 non-null category
# A1Cresult                   100110 non-null category
# metformin                   100110 non-null category
# repaglinide                 100110 non-null category
# nateglinide                 100110 non-null category
# chlorpropamide              100110 non-null category
# glimepiride                 100110 non-null category
# acetohexamide               100110 non-null category
# glipizide                   100110 non-null category
# glyburide                   100110 non-null category
# tolbutamide                 100110 non-null category
# pioglitazone                100110 non-null category
# rosiglitazone               100110 non-null category
# acarbose                    100110 non-null category
# miglitol                    100110 non-null category
# troglitazone                100110 non-null category
# tolazamide                  100110 non-null category
# insulin                     100110 non-null category
# glyburide-metformin         100110 non-null category
# glipizide-metformin         100110 non-null category
# glimepiride-pioglitazone    100110 non-null category
# metformin-rosiglitazone     100110 non-null category
# metformin-pioglitazone      100110 non-null category
# change                      100110 non-null category
# diabetesMed                 100110 non-null category
# readmitted                  100110 non-null category
# visit_num                   0 non-null float64
# dtypes: category(34), float64(2), int64(8)
# memory usage: 11.7 MB

# %%
condition = df_clean.readmitted != 'NO'
df_numeric_2 = df_numeric_1[condition]
condition3 = df_clean.readmitted[condition] != '<30'
numeric_col = ['age','time_in_hospital','num_lab_procedures','num_procedures','num_medications','number_outpatient','number_emergency',
      'number_inpatient','number_diagnoses' ,'visit_num']

# %%
# %%time
#Defining our test statistics 
reps_diff_of_mean = pd.DataFrame(columns = numeric_col)
obs_diff_of_mean = np.empty(shape = 10)

#Loop to calculate P-value for each columns
for i in range(10):
    #Sample for Readmission
    s1 = df_numeric_2[condition3].iloc[:,i]
    n1 = len(s1)
    
    #Sample for Non-Readmission
    s0 = df_numeric_2[~condition3].iloc[:,i]
    n0 = len(s0)

    #Calculating overall mean of the column
    combined_mean = np.mean(df_numeric_2.iloc[:,i])
    
    #Observed difference of mean between two samples
    obs_diff_of_mean[i] = np.mean(s1) - np.mean(s0)

    #Shifting the data for Bootstrapping
    shifted_0 = s0+combined_mean-np.mean(s0)
    shifted_1 = s1+combined_mean-np.mean(s1)

    #Calculating bootstrap replicates
    bs_reps_0 = draw_bs_reps(shifted_0,np.mean,size = N_rep)
    bs_reps_1 = draw_bs_reps(shifted_1,np.mean,size = N_rep)

    #Calculating difference of means for replicates
    reps_diff_of_mean.iloc[:,i] = bs_reps_1 - bs_reps_0
    
    #Calculating p-value
    if obs_diff_of_mean[i] >0:
        p = np.sum(reps_diff_of_mean.iloc[:,i] >= obs_diff_of_mean[i]) / len(reps_diff_of_mean.iloc[:,i])
    else:
        p = np.sum(reps_diff_of_mean.iloc[:,i] <= obs_diff_of_mean[i]) / len(reps_diff_of_mean.iloc[:,i])
    
    print(numeric_col[i], ' p-value =', p*2)
# Out:
# age  p-value = 0.0
# time_in_hospital  p-value = 0.0
# num_lab_procedures  p-value = 0.0635
# num_procedures  p-value = 0.0783
# num_medications  p-value = 0.0
# number_outpatient  p-value = 0.0
# number_emergency  p-value = 0.0
# number_inpatient  p-value = 0.0
# number_diagnoses  p-value = 0.0166
# visit_num  p-value = 0.0
# Wall time: 3min 16s

# %%
#Making bin size equal to number of unique values in the columns 
bins = [ len(df_numeric_1.iloc[:,i].unique()) for i in range(len(numeric_col))]

x = [1,2,3,4,5,6,7,8]

#For Loop to plot graphs for all the features together
for i in range(4):
    plt.subplot(4,2, x[2*i])
    plt.title(numeric_col[2*i])
    plt.hist(df_numeric_1[condition3].iloc[:,2*i],bins = bins[2*i], alpha = 0.5, label='1', density = True, histtype = 'stepfilled')
    plt.hist(df_numeric_1[~condition3].iloc[:,2*i],bins = bins[2*i], alpha = 0.5, label='0', density = True, histtype = 'stepfilled')
    #plt.hist(df_numeric[condition3].iloc[:,2*i],bins = bins[2*i], alpha = 0.5, label='NO', density = True, histtype = 'stepfilled')
    if((numeric_col[2*i] == 'number_inpatient') | (numeric_col[2*i] == 'number_outpatient') | 
       (numeric_col[2*i] == 'number_emergency')):
        plt.yscale('log')
    plt.legend()

    plt.subplot(4,2, x[2*i + 1])
    plt.title(numeric_col[2*i + 1])
    plt.hist(df_numeric_1[condition3].iloc[:,2*i + 1],bins = bins[2*i + 1], alpha = 0.5, label='1', density = True, histtype = 'stepfilled')
    plt.hist(df_numeric_1[~condition3].iloc[:,2*i + 1],bins = bins[2*i + 1], alpha = 0.5, label='0', density = True, histtype = 'stepfilled')
    #plt.hist(df_numeric[condition3].iloc[:,2*i + 1],bins = bins[2*i + 1], alpha = 0.5, label='NO', density = True, histtype = 'stepfilled')
    if((numeric_col[2*i+1] == 'number_inpatient') | (numeric_col[2*i] == 'number_outpatient') | (numeric_col[2*i] == 'number_emergency')):
        plt.yscale('log')    
    if(numeric_col[2*i+1] == 'number_diagnoses'):
        plt.legend(loc = 'upper left')
    else:
        plt.legend()
    
plt.tight_layout()
